# %% [markdown]
# # Import Library

# %%
# Import Library
import pandas as pd
import os
from dotenv import load_dotenv
import pymongo
from pymongo import MongoClient
from langchain_openai import ChatOpenAI
from langchain_mongodb import MongoDBAtlasVectorSearch
from langchain.chains import RetrievalQA
from langchain import PromptTemplate
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain.chat_models import ChatOpenAI
import re

# %% [markdown]
# # Set Up

# %%
# Load semua environment
load_dotenv()
MONGODB_URI = os.getenv("MONGODB_URI")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
DEEPSEEK_API_NEW=os.getenv("DEEPSEEK_API_NEW")

# %%
# Embeding menggunakan gemini
embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key=GOOGLE_API_KEY,
)

# %%
# MongoDB Connection ke
client = MongoClient(MONGODB_URI)
collection = client['finalproject_db']['faq_300']

# %%
# Vector Store Configuration
vector_store = MongoDBAtlasVectorSearch(
    collection=collection,
    embedding=embeddings,
    index_name='vector_index',
)

# %%
# Prompt Template
PROFESSIONAL_PROMPT = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    Anda adalah Asisten Virtual Resmi BPJS Indonesia.

    Peran Anda:
    Anda bertindak sebagai Customer Service (Layanan Pelanggan) untuk membantu masyarakat dalam memahami layanan dan prosedur dari:
    - Website BPJS Kesehatan
    - FAQ BPJS Ketenagakerjaan
    - FAQ Aplikasi JKN Mobile

    Tugas & Tanggung Jawab:
    1. Memberikan jawaban akurat, terpercaya, dan relevan sesuai dengan data dari sumber resmi (FAQ).
    2. Menjelaskan prosedur atau solusi dengan cara yang mudah dimengerti, terstruktur, dan menggunakan Bahasa Indonesia baku.
    3. Menjadi perantara informasi yang ramah, efisien, dan profesional dalam menangani keluhan atau pertanyaan pengguna.
    4. Jawablah dengan ringkas, jangan menjawab hal yang tidak ditanyakan
    5. Pertanyaan mungkin menggunakan bahasa tidak baku atau typo, sehingga anda harus paham perbedaannya dengan konteks yang berada diluar FAQ.
    7. Periksalah apakah pertanyaan merupakan suatu singkatan, yang mungkin terdapat jawabannya di dataset.

    Aturan yang Wajib Dipatuhi:
    1. Jawab hanya berdasarkan informasi yang tersedia dalam dokumen FAQ resmi.
    2. Jangan mengarang jawaban atau memberikan informasi tambahan yang tidak tercantum dalam sumber resmi.
    3. Jika pertanyaan tidak relevan atau tidak tersedia dalam data, sampaikan secara sopan bahwa Anda tidak memiliki informasi tersebut.
    4. Dilarang mencantumkan tautan eksternal, nomor telepon, alamat, atau informasi pribadi lain yang tidak ada dalam dokumen FAQ, jika ada diperbolehkan.
    5. Gunakan:
    - Penomoran (1., 2., 3., dst) untuk menjelaskan langkah atau prosedur berurutan.
    - Simbol bullet (•) untuk daftar yang tidak berurutan.

    Konteks resmi:
    {context}

    Pertanyaan: {question}

    Jawaban profesional:
    """
)

# %%
# Config model untuk Deepseek
llm_deepseek = ChatOpenAI(
    model="deepseek-chat",  
    openai_api_key=DEEPSEEK_API_NEW,  
    base_url="https://api.deepseek.com/v1",  
    temperature=0,
    max_tokens=500
)

# %%
# Retrieval Chain
qa = RetrievalQA.from_chain_type(
    llm=llm_deepseek,
    chain_type="stuff",
    retriever=vector_store.as_retriever(
        search_type="similarity",
        search_kwargs={
            "k": 5,
            "score_threshold": 0.70
        }
    ),
    chain_type_kwargs={"prompt": PROFESSIONAL_PROMPT},
)

# %%
# Ambil data
faq_df = pd.read_csv('../data/final_dataset_clean.csv')
def answer_from_doc(question):
    """Fungsi untuk mencocokkan pertanyaan dengan data yang sama persis dan mengambil jawaban"""
    row = faq_df[faq_df['question'] == question]
    if not row.empty:
        return row.iloc[-1]['answer']
    else:
        return "Tidak ada jawaban."

# %%
def clean_answer(text):
    """Hilangkan tanda bold/italic Markdown"""
    text = re.sub(r'\*\*(.*?)\*\*', r'\1', text)
    text = re.sub(r'\*(.*?)\*', r'\1', text)
    cleaned_text = re.sub(r'\n{3,}', '\n\n', text)
    return cleaned_text.strip()

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Test Case 1 Pertanyaan Dataset

# %%
# UJI COBA 1: Pertanyaan yang Seharusnya Bisa Dijawab karena berasal dari dataset
questions = [
# Mobile
"Bagaimana cara menginstall aplikasi Jamsostek Mobile (JMO)?",
"Bagaimana cara mengajukan klaim JHT melalui JMO jika memiliki lebih dari 1 kartu?",
"Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?",
"Jika anggota baru di JMO, apakah harus mendaftar di MotionPay?",
"Apakah itu Promo?",
"Apakah itu MotionPay?",
"Apakah sandi/PIN harus diubah secara berkala di kedua aplikasi?",
"Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?",

# Ketenagakerjaan
"Apa itu BPJS Ketenagakerjaan?",
"Apa saja program BPJS Ketenagakerjaan?",
"Siapakah yang dimaksud peserta BPJS Ketenagakerjaan?",
"Apakah yang dimaksud dengan PHK?",
"Apakah pegawai BHL (Buruh Harian Lepas) dapat mengikuti program JKP?",
"Bagaimana caranya badan usaha/pemberi kerja dapat menggunakan layanan Payment Reminder System(PRS)?",
"Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?",
"Apakah aplikasi Electronic Payment System (EPS)?",
"Apa perbedaan program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP)?",

# Kesehatan
"Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan ?",
"Bagaimana Mendaftarkan Bayi Baru Lahir ?",
"Dimana kontak kantor BPJS Kesehatan ?",
"Apa itu GRC ?",
"Cara Membayar Iuran",
"Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan ?",
"Kapan pembayaran iuran paling lambat ?",
"Bagaimana komitmen BPJS Kesehatan terkait gratifikasi ?"
]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    result = qa.invoke({"query": q})
    print(clean_answer(result['result']))
    print(f"\nACTUAL DATA: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: Bagaimana cara menginstall aplikasi Jamsostek Mobile (JMO)?
# Untuk menginstal aplikasi Jamsostek Mobile (JMO), berikut langkah-langkahnya:
#
# 1. Buka Google Play Store (Android) atau App Store (iOS) di perangkat Anda.
# 2. Cari "Jamsostek Mobile" di kolom pencarian.
# 3. Pilih aplikasi resmi yang diterbitkan oleh BPJS Ketenagakerjaan.
# 4. Klik "Instal" dan tunggu proses pengunduhan selesai.
# 5. Buka aplikasi dan ikuti panduan registrasi/login sesuai kebutuhan.
#
# Pastikan perangkat Anda terhubung dengan internet dan memiliki ruang penyimpanan yang cukup.
#
# Jika mengalami kendala, pastikan aplikasi yang diunduh adalah versi terbaru dan sesuai dengan sistem operasi perangkat Anda.
#
# ACTUAL DATA: Aplikasi Jamsostek Mobile (JMO) dapat diunduh dan diinstall melalui Playstore/ Appstore bagi pengguna smartphone .
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara mengajukan klaim JHT melalui JMO jika memiliki lebih dari 1 kartu?
# Untuk mengajukan klaim Jaminan Hari Tua (JHT) melalui JMO (Jamsostek Mobile) jika memiliki lebih dari 1 kartu, berikut langkah-langkahnya:
#
# 1. Pastikan semua kartu aktif dan terdaftar dalam satu akun JMO.
# 2. Login ke aplikasi JMO menggunakan akun yang terdaftar.
# 3. Pilih menu Klaim JHT dan ikuti petunjuk pengisian data.
# 4. Sertakan nomor kartu tambahan saat diminta data kepesertaan.
# 5. Unggah dokumen pendukung yang diperlukan (sesuai ketentuan).
#
# Jika mengalami kendala, pastikan:
# • Data kepesertaan semua kartu sudah terintegrasi di sistem BPJS Ketenagakerjaan.
# • Tidak ada tunggakan iuran pada kartu-kartu tersebut.
#
# Informasi lebih lanjut dapat dilihat di FAQ BPJS Ketenagakerjaan atau hubungi layanan pelanggan resmi BPJS.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# Maaf, saat ini tidak ada informasi resmi mengenai promo yang tersedia pada aplikasi Jamsostek Mobile (JMO) dalam dokumen FAQ BPJS Ketenagakerjaan. Untuk informasi lebih lanjut, Anda dapat memeriksa langsung melalui aplikasi JMO atau menghubungi layanan pelanggan BPJS Ketenagakerjaan.
#
# Terima kasih.
#
# ACTUAL DATA: Promo yang tersedia merupakan produk dari berbagai merchant yang bekerjasama dengan BPJS Ketenagakerjaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Jika anggota baru di JMO, apakah harus mendaftar di MotionPay?
# Maaf, saya tidak memiliki informasi resmi terkait pertanyaan Anda tentang pendaftaran MotionPay untuk anggota baru di JMO.
#
# Untuk pertanyaan terkait layanan BPJS Kesehatan atau BPJS Ketenagakerjaan, silakan sampaikan detail pertanyaan Anda agar saya dapat membantu sesuai prosedur yang tersedia.
#
# Anda juga dapat mengunjungi website resmi BPJS Kesehatan atau BPJS Ketenagakerjaan untuk informasi lebih lanjut.
#
# Terima kasih.
#
# ACTUAL DATA: Pengguna baru dapat mendaftar dengan mengakses fitur e-Wallet pada aplikasi JMO.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah itu Promo?
# Maaf, saya tidak memiliki informasi resmi terkait istilah "Promo" dalam konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile berdasarkan dokumen FAQ yang tersedia.
#
# Untuk pertanyaan lebih lanjut, Anda dapat mengunjungi situs resmi BPJS Kesehatan atau BPJS Ketenagakerjaan.
#
# Saya dengan senang hati membantu jika Anda memiliki pertanyaan lain terkait layanan BPJS.
#
# ACTUAL DATA: Fitur promo ditujukan kepada peserta BPJS Ketenagakerjaan untuk mendapatkan diskon dan penawaran menarik
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah itu MotionPay?
# Mohon maaf, saya tidak memiliki informasi resmi terkait MotionPay dalam dokumen FAQ BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Untuk pertanyaan seputar layanan BPJS, Anda dapat menyampaikan pertanyaan yang lebih spesifik terkait:
# • Website BPJS Kesehatan
# • Layanan BPJS Ketenagakerjaan
# • Aplikasi JKN Mobile
#
# Saya dengan senang hati akan membantu sesuai informasi yang tersedia.
#
# ACTUAL DATA: Aplikasi uang elektronik milik PT. MNC Teknologi Nusantara.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah sandi/PIN harus diubah secara berkala di kedua aplikasi?
# Berdasarkan informasi resmi BPJS Kesehatan dan BPJS Ketenagakerjaan:
#
# 1. Aplikasi JKN Mobile:
#    • Tidak ada ketentuan wajib untuk mengubah sandi/PIN secara berkala. Namun, disarankan untuk mengganti secara berkala demi keamanan akun.
#
# 2. Aplikasi BPJS Ketenagakerjaan:
#    • Saat ini tidak terdapat aturan yang mewajibkan perubahan sandi/PIN secara berkala.
#
# Jika Anda memerlukan bantuan lebih lanjut, silakan hubungi layanan pelanggan resmi BPJS.
#
# ACTUAL DATA: Untuk keamanan dan kenyamanan pengguna, maka sandi/PIN harus diubah secara berkala di kedua aplikasi.
# ==================================================
#
# ==================================================
# Pertanyaan: Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# Maaf, saat ini tidak ada informasi mengenai promo yang tersedia pada aplikasi Jamsostek Mobile (JMO) dalam dokumen resmi BPJS Ketenagakerjaan. Untuk informasi lebih lanjut, Anda dapat memeriksa update terbaru melalui aplikasi JMO atau menghubungi layanan pelanggan BPJS Ketenagakerjaan.
#
# Terima kasih.
#
# ACTUAL DATA: Promo yang tersedia merupakan produk dari berbagai merchant yang bekerjasama dengan BPJS Ketenagakerjaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa itu BPJS Ketenagakerjaan?
# BPJS Ketenagakerjaan adalah program perlindungan sosial yang dikelola oleh Badan Penyelenggara Jaminan Sosial (BPJS) untuk memberikan jaminan kepada tenaga kerja di Indonesia. Program ini mencakup beberapa manfaat, seperti:
#
# • Jaminan Kecelakaan Kerja (JKK)
# • Jaminan Hari Tua (JHT)
# • Jaminan Pensiun (JP)
# • Jaminan Kematian (JKm)
#
# Tujuannya adalah melindungi pekerja dari risiko ekonomi akibat kecelakaan kerja, pensiun, atau kehilangan penghasilan. Peserta wajib membayar iuran sesuai ketentuan yang berlaku.
#
# Informasi lebih lanjut dapat dilihat di [situs resmi BPJS Ketenagakerjaan](https://www.bpjsketenagakerjaan.go.id/).
#
# ACTUAL DATA: BPJS Ketenagakerjaan adalah badan hukum yang dibentuk untuk menyelenggarakan program Jaminan Kecelakaan Kerja, Jaminan Hari Tua, Jaminan Pensiun, Jaminan Kematian dan Jaminan Kehilangan Pekerjaan yang bertujuan untuk memberikan perlindungan paripurna kepada seluruh pekerja di Indonesia.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa saja program BPJS Ketenagakerjaan?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, berikut program yang disediakan:
#
# 1. Jaminan Hari Tua (JHT)
#    • Perlindungan untuk peserta saat memasuki masa pensiun, meninggal dunia, atau mengalami cacat total tetap.
#
# 2. Jaminan Kecelakaan Kerja (JKK)
#    • Memberikan manfaat berupa perawatan dan santunan jika peserta mengalami kecelakaan saat bekerja atau dalam perjalanan kerja.
#
# 3. Jaminan Kematian (JKM)
#    • Memberikan santunan kepada ahli waris jika peserta meninggal dunia (bukan akibat kecelakaan kerja).
#
# 4. Jaminan Pensiun (JP)
#    • Memberikan manfaat pensiun bulanan setelah peserta memenuhi syarat usia atau masa kepesertaan.
#
# Semua program diatur sesuai ketentuan undang-undang dan peraturan BPJS Ketenagakerjaan. Untuk detail lebih lanjut, Anda dapat mengunjungi situs resmi BPJS Ketenagakerjaan.
#
# ACTUAL DATA: Program yang diselenggarakan oleh BPJS Ketenagakerjaan terdiri dari 5 (lima) program, yaitu Jaminan Kecelakaan, Jaminan Hari Tua, Jaminan Pensiun, Jaminan Kematian dan dan Jaminan Kehilangan Pekerjaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapakah yang dimaksud peserta BPJS Ketenagakerjaan?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, yang dimaksud dengan peserta adalah:
#
# • Pekerja penerima upah:
#   - PNS/TNI/Polri
#   - Pegawai BUMN/BUMD
#   - Pegawai swasta
#   - Pekerja migran Indonesia
#
# • Pekerja bukan penerima upah:
#   - Pekerja mandiri (wiraswasta, freelancer, dll.)
#   - Pekerja di sektor informal
#
# • Peserta lain yang ditetapkan pemerintah:
#   - Penerima bantuan iuran dari program tertentu.
#
# Informasi lebih detail dapat dilihat pada dokumen resmi BPJS Ketenagakerjaan.
#
# ACTUAL DATA: Program yang diselenggarakan oleh BPJS Ketenagakerjaan terdiri dari 5 (lima) program, yaitu Jaminan Kecelakaan, Jaminan Hari Tua, Jaminan Pensiun, Jaminan Kematian dan dan Jaminan Kehilangan Pekerjaan., Peserta BPJS Ketenagakerjaan terdiri dari:, Peserta Penerima Upah yang meliputi: Pekerja yang bekerja pada Pemberi Kerja penyelenggara negara meliputi: Pegawai pemerintah non-pegawai negeri Pejabat negara non-aparatur sipil negara dan Pegawai non-aparatur sipil negara pada lembaga tinggi negara atau lembaga negara. Pekerja yang bekerja pada Pemberi Kerja selain Penyelenggara Negara meliputi: Pekerja pada perusahaan Pekerja pada orang perseorangan Orang asing yang bekerja di Indonesia paling singkat 6 (enam) bulan Pekerja dalam masa percobaan Komisaris dan direksi yang menerima upah dan Pengawas dan pengurus yang menerima upah. Peserta Bukan Penerima Upah yang meliputi: Pemberi kerja Pekerja di luar hubungan kerja atau pekerja mandiri Pekerja yang tidak termasuk huruf b. yang bukan menerima upah. Pekerja Migran Indonesia adalah setiap warga negara Indonesia yang akan, sedang, atau telah melakukan pekerjaan dengan menerima upah di luar wilayah Republik Indonesia. Peserta Sektor Jasa Konstruksi meliputi Pekerja harian lepas, borongan, dan perjanjian kerja waktu tertentu di sektor Jasa Konstruksi.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah yang dimaksud dengan PHK?
# Jawaban:
#
# PHK (Pemutusan Hubungan Kerja) adalah pengakhiran hubungan kerja antara pekerja dan pemberi kerja karena alasan tertentu, seperti:
# • Keinginan perusahaan (misalnya: efisiensi, penutupan usaha).
# • Pelanggaran peraturan oleh pekerja.
# • Perusahaan mengalami kebangkrutan.
#
# Dampak pada BPJS Ketenagakerjaan:
# 1. Pekerja tetap berhak mendapatkan manfaat program Jaminan Hari Tua (JHT) atau Jaminan Pensiun (JP) sesuai ketentuan.
# 2. Jika memenuhi syarat, pekerja dapat mengajukan klaim Jaminan Kehilangan Pekerjaan (JKP).
#
# Informasi lebih lanjut dapat dilihat pada FAQ BPJS Ketenagakerjaan di sumber resmi.
#
# (Jawaban merujuk pada ketentuan resmi BPJS Ketenagakerjaan terkait PHK dan hak peserta.)
#
# ACTUAL DATA: Pengakhiran hubungan kerja karena suatu hal tertentu yang mengakibatkan berakhirnya hak dan kewajiban antara Pekerja/Buruh dan Pengusaha.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah pegawai BHL (Buruh Harian Lepas) dapat mengikuti program JKP?
# Berdasarkan ketentuan BPJS Ketenagakerjaan, Buruh Harian Lepas (BHL) tidak termasuk dalam peserta program Jaminan Kehilangan Pekerjaan (JKP).
#
# Program JKP hanya berlaku untuk:
# • Peserta BPJS Ketenagakerjaan yang terdaftar sebagai pekerja penerima upah (karyawan tetap/non-tetap di perusahaan).
# • Memenuhi persyaratan tertentu seperti masa kepesertaan minimal 12 bulan dan mengalami Pemutusan Hubungan Kerja (PHK) bukan karena kesalahan sendiri.
#
# Untuk informasi lebih lanjut, Anda dapat merujuk ke FAQ resmi BPJS Ketenagakerjaan atau menghubungi layanan pelanggan BPJS Ketenagakerjaan.
#
# Catatan: Jawaban ini berdasarkan data resmi BPJS Ketenagakerjaan dan mungkin diperbarui sesuai regulasi terbaru.
#
# ACTUAL DATA: Contohnya BHL Apakah saat perusahaan baru pada sektor perkebunan?, Setiap Pekerja dengan status PKWT maupun PKWTT yang memenuhi eligibilitas dapat menjadi peserta program JKP, sebagaimana dinyatakan dalam PP 37 tahun 2021 pasal 1 yang menyatakan bahwa peserta Program JKP adalah Pekerja/Buruh yang mempunyai hubungan kerja dan menerima upah atau imbalan bentuk lainnya.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana caranya badan usaha/pemberi kerja dapat menggunakan layanan Payment Reminder System(PRS)?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, berikut cara badan usaha/pemberi kerja menggunakan layanan Payment Reminder System (PRS):
#
# 1. Akses PRS:
#    • Login ke akun BPJSTK employer melalui website resmi BPJS Ketenagakerjaan.
#
# 2. Aktifkan Layanan:
#    • Pilih menu Payment Reminder System di dashboard.
#    • Ikuti petunjuk untuk mengaktifkan notifikasi pembayaran.
#
# 3. Penerima Notifikasi:
#    • Masukkan email dan nomor telepon yang akan menerima reminder pembayaran iuran.
#
# 4. Jadwal Notifikasi:
#    • Sistem akan mengirimkan peringatan otomatis via email/SMS sebelum jatuh tempo pembayaran.
#
# Catatan: Pastikan data kontak yang didaftarkan valid agar notifikasi dapat diterima tepat waktu.
#
# Jika ada kendala teknis, disarankan menghubungi kontak resmi BPJS Ketenagakerjaan melalui saluran yang tersedia di website.
#
# ACTUAL DATA: Untuk menggunakan layanan Payment Reminder System (PRS) setiap bulannya, badan usaha/pemberi kerja dapat mendaftar melalui Petugas BPJS Ketenagakerjaan Kantor Cabang kepesertaan dengan menandatangani formulir pendaftaran PRS dan dipastikan menggunakan nomor handphone yang valid dan jika terjadi perubahan nomor handphone harap dilaporkan ke Petugas BPJS Ketenagakerjaan Kantor Cabang kepesertaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, berikut langkah yang dapat dilakukan jika pembayaran iuran BPU (BPJS Ketenagakerjaan) belum memperbarui masa perlindungan/saldo JHT:
#
# 1. Pastikan bukti pembayaran valid (contoh: struk pembayaran, notifikasi transfer, atau kode billing yang tercatat).
# 2. Cek status pembayaran melalui:
#    • Aplikasi JKN Mobile (menu Riwayat Pembayaran)
#    • Website BPJS Ketenagakerjaan (fitur cek iuran)
# 3. Jika pembayaran sudah terverifikasi tetapi saldo/masa perlindungan belum update, laporkan ke kantor BPJS Ketenagakerjaan terdekat dengan membawa bukti pembayaran untuk proses lebih lanjut.
#
# Catatan: Proses sinkronisasi data membutuhkan waktu maksimal 2x24 jam kerja setelah pembayaran. Jika melebihi waktu tersebut, silakan hubungi layanan pelanggan BPJS Ketenagakerjaan.
#
# Mohon maaf, saya tidak dapat memberikan informasi di luar prosedur resmi ini. Untuk pertanyaan lebih lanjut, Anda dapat merujuk ke FAQ BPJS Ketenagakerjaan atau mengunjungi kantor cabang.
#
# ACTUAL DATA: Peserta dapat menunjukkan tanda bukti pembayaran dari kanal pembayaran iuran dimana Peserta melakukan transaksi pembayaran iuran. Selanjutnya laporan akan ditindaklanjuti segera oleh tim BPJS Ketenagakerjaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah aplikasi Electronic Payment System (EPS)?
# Maaf, saya tidak memiliki informasi resmi terkait aplikasi Electronic Payment System (EPS) dalam konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Untuk pertanyaan lebih lanjut, Anda dapat menghubungi layanan pelanggan resmi BPJS melalui saluran komunikasi yang tersedia di website atau aplikasi resmi BPJS.
#
# Terima kasih.
#
# ACTUAL DATA: Electronic Payment System (EPS), adalah sistem pembayaran iuran BPJS Ketenagakerjaan secara Host to Host antara perbankan dengan BPJS Ketenagakerjaan. EPS disediakan untuk memudahkan perusahaan peserta dalam melakukan monitoring pembayaran iuran.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa perbedaan program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP)?
# Berikut perbedaan antara program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP) berdasarkan ketentuan BPJS Ketenagakerjaan:
#
# 1. Jaminan Hari Tua (JHT)
# • Tujuan: Memberikan manfaat berupa uang tunai saat peserta memasuki usia pensiun, meninggal dunia, atau mengalami cacat total tetap.
# • Sumber Iuran: Dibayar oleh pekerja dan pemberi kerja (patungan).
# • Waktu Pencairan:
#   - Usia 56 tahun (pensiun).
#   - Meninggal dunia (ahli waris berhak).
#   - Cacat total tetap akibat kecelakaan kerja.
#
# 2. Jaminan Pensiun (JP)
# • Tujuan: Memberikan penghasilan bulanan setelah peserta pensiun atau mengalami cacat total tetap.
# • Sumber Iuran: Dibayar penuh oleh pemberi kerja.
# • Manfaat:
#   - Pensiun normal (usia 58 tahun).
#   - Pensiun dini (usia 56 tahun dengan syarat tertentu).
#   - Pensiun karena cacat total tetap.
#
# Perbedaan Utama:
# - JHT berbentuk tabungan satu kali cair, sedangkan JP memberikan manfaat bulanan berkala.
# - Iuran JHT bersifat akumulatif, sementara JP dihitung berdasarkan masa kerja dan upah.
#
# Informasi lebih detail dapat dilihat di [situs resmi BPJS Ketenagakerjaan](https://www.bpjsketenagakerjaan.go.id/).
#
# ACTUAL DATA: Ditinjau dari manfaatnya, JHT merupakan manfaat uang tunai yang dibayarkan sekaligus pada saat pekerja memasuki usia pensiun, meninggal dunia, atau mengalami cacat total tetap., , Sedangkan manfaat JP adalah manfaat uang tunai yang dibayarkan setiap bulan kepada peserta yang memasuki usia pensiun, mengalami cacat total tetap, atau kepada Ahli Waris bagi peserta yang meninggal dunia., , Usia pensiun yang ditetapkan pertama kali adalah 56 tahun. Mulai 1 Januari 2019, usia pensiun bertambah menjadi 57 tahun. Usia pensiun dimaksud selanjutnya bertambah 1 (satu) tahun untuk setiap 3 (tiga) tahun berikutnya sampai mencapai usia pensiun maksimal 65 tahun.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan ?
# Berikut adalah layanan BPJS Kesehatan yang dapat dimanfaatkan oleh peserta:
#
# 1. Pelayanan Kesehatan Tingkat Pertama (FKTP)
#    • Puskesmas
#    • Klinik (termasuk pratama, utama, dan mandiri)
#    • Dokter praktik perorangan
#    • Rumah sakit kelas D pratama
#
# 2. Pelayanan Kesehatan Rujukan Tingkat Lanjutan (FKRTL)
#    • Rumah sakit (kelas A, B, C, atau D)
#    • Klinik khusus atau penunjang (atas rujukan FKTP)
#
# 3. Pelayanan Darurat
#    • Penanganan gawat darurat di fasilitas kesehatan mana pun, termasuk non-JKN.
#
# 4. Program Jaminan Kesehatan Nasional (JKN)
#    • Rawat inap
#    • Rawat jalan
#    • Persalinan
#    • Pelayanan obat dan bahan medis
#    • Rehabilitasi medis
#
# 5. Layanan Tambahan (jika berlaku)
#    • Pemeriksaan kesehatan berkala (sesuai ketentuan)
#    • Vaksinasi dasar (untuk anak sesuai program pemerintah)
#
# Pastikan membawa kartu peserta saat mengakses layanan. Jika ada pertanyaan lebih lanjut, silakan hubungi kontak resmi BPJS Kesehatan.
#
# ACTUAL DATA: - Pelayanan Kesehatan Tingkat Pertama, Pelayanan Kesehatan Tingkat Pertama adalah pelayanan kesehatan perorangan yang bersifat non spesialistik (primer) meliputi pelayanan rawat jalan dan rawat inap yang diberikan oleh Fasilitas Kesehatan Tingkat Pertama (FKTP) :, - Puskesmas atau yang setara, - Praktik Mandiri Dokter, - Praktik Mandiri Dokter Gigi, - Klinik pratama atau yang setara, termasuk Fasilitas Kesehatan Tingkat Pertama (FKTP) milik TNI/Polri, - Rumah Sakit Kelas D Pratama atau yang setara, - Fasilitas kesehatan penunjang seperti apotek dan laboratorium., , - Rawat Jalan Tingkat Pertama, Merupakan pelayanan kesehatan perorangan yang bersifat non spesialistik yang dilaksanakan pada FKTP untuk keperluan observasi, diagnosis, pengobatan, dan/atau pelayanan kesehatan lainnya., Jenis pelayanan RJTP meliputi: administrasi pelayanan, termasuk biaya administrasi pendaftaran peserta untuk berobat, penyediaan, dan pemberian surat rujukan ke FKRTL untuk penyakit yang tidak dapat ditangani di FKTP, pelayanan promotif dan preventif perorangan, meliputi kegiatan penyuluhan kesehatan perorangan, imunisasi rutin, keluarga berencana, skrining riwayat kesehatan dan pelayanan penapisan atau skrining kesehatan tertentu, dan pelayanan Program Pengelolaan Penyakit Kronis, - Pemeriksaan, pengobatan, dan konsultasi medis, - Pemeriksaan ibu hamil, nifas, ibu menyusui, bayi dan anak balita, - Tindakan medis non spesialistik, baik operatif maupun non operatif, - Pelayanan obat, alat kesehatan, dan bahan medis habis pakai, - Pemeriksaan penunjang diagnostik laboratorium tingkat pratama, - Pelayanan Program Rujuk Balik, , - Rawat Inap Tingkat Pertama, Manfaat yang ditanggung:, 1. Pendaftaran dan administrasi, 2. Akomodasi rawat inap, 3. Pemeriksaan, pengobatan dan konsultasi medis, 4. Tindakan medis non spesialistik, baik operatif maupun non operatif, 5. Pelayanan kebidanan, ibu, bayi dan balita meliputi : , - Persalinan pervaginam bukan risiko tinggi, - Persalinan dengan komplikasi dan/atau penyulit pervaginam bagi Puskesmas PONED (Pelayanan Obstetri Neonatus Emergensi Dasar), - Pertolongan neonatal dengan komplikasi, 6. Pelayanan obat dan bahan medis habis pakai, 7. Pemeriksaan penunjang diagnostik laboratorium tingkat pratama., , - Pelayanan Kesehatan Rujukan Tingkat Lanjutan, Pelayanan Kesehatan Rujukan Tingkat Lanjutan adalah upaya pelayanan kesehatan perorangan yang bersifat spesialistik atau sub spesialistik yang meliputi rawat jalan tingkat lanjutan, rawat inap tingkat lanjutan, dan rawat inap di ruang perawatan khusus, yang diberikan oleh:, - Klinik utama atau yang setara., - Rumah Sakit Umum baik milik Pemerintah maupun Swasta, - Rumah Sakit Khusus, - Faskes Penunjang: Apotik, Optik dan Laboratorium, , - Rawat Jalan Tingkat Lanjut, Manfaat yang ditanggung :, 1. Administrasi pelayanan, 2. Pemeriksaan, pengobatan, dan konsultasi medis dasar yang dilakukan di unit gawat darurat, 3. Pemeriksaan, pengobatan, dan konsultasi spesialistik, 4. Tindakan medis spesialistik, baik bedah maupun non bedah sesuai dengan indikasi medis, 5. Pelayanan obat, alat kesehatan dan bahan medis habis pakai, 6. Pelayanan penunjang diagnostik lanjutan (laboratorium, radiologi dan penunjang diagnostik lainnya) sesuai dengan indikasi medis, 7. Rehabilitasi medis, 8. Pelayanan darah., , - Rawat Inap Tingkat Lanjut, Manfaat yang ditanggung, 1. Perawatan inap non intensif, 2. Perawatan inap intensif (ICU, ICCU, NICU, PICU).
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana Mendaftarkan Bayi Baru Lahir ?
# Berikut adalah prosedur pendaftaran BPJS Kesehatan untuk bayi baru lahir berdasarkan ketentuan resmi:
#
# 1. Persyaratan:
# • Akta kelahiran bayi (dari Dinas Kependudukan dan Catatan Sipil/Dukcapil).
# • Kartu Keluarga (KK) yang telah memuat nama bayi.
# • Nomor induk kependudukan (NIK) bayi.
#
# 2. Prosedur Pendaftaran:
# • Bayi otomatis terdaftar dalam program JKN-KIS selama 90 hari setelah kelahiran jika ibu aktif sebagai peserta BPJS Kesehatan.
# • Setelah 90 hari, lakukan pendaftaran mandiri dengan:
#   1. Datang ke kantor BPJS Kesehatan terdekat atau mitra (bank/pos).
#   2. Serahkan dokumen persyaratan.
#   3. Bayar iuran pertama (jika termasuk kategori PBPU/Pesepeda Mandiri).
#
# Catatan:
# • Bayi dari peserta PBI APBN tidak dikenakan iuran.
# • Pastikan data bayi sudah tercantum dalam KK sebelum mendaftar.
#
# Jika ada pertanyaan lebih lanjut, silakan hubungi layanan BPJS Kesehatan melalui saluran resmi.
#
# ACTUAL DATA: Ketentuan umum administrasi kepesertaan bagi bayi baru lahir antara lain:, , 1. Bayi baru lahir dari Peserta JKN-KIS wajib didaftarkan kepada BPJS Kesehatan dan membayar iuran paling lambat 28 (dua puluh delapan) hari sejak dilahirkan;, 2. Status bayi baru lahir akan aktif setelah dilakukan pembayaran iuran;, 3. Bayi baru lahir yang sudah terdaftar sebagai peserta JKN KIS wajib melakukan pemutakhiran data NIK Padan Dukcapil paling lambat 3 (tiga) bulan sejak dilahirkan;, 4. Pendaftaran bayi yang berusia lebih dari 3 bulan wajib memiliki NIK yang terdaftar pada Dukcapil;, 5. Peserta yang tidak mendaftar dan membayar iuran bayi baru lahir paling lama 28 hari sejak dilahirkan dikenakan kewajiban membayar iuran sejak bayi dilahirkan dan dikenakan sanksi sebagaimana sanksi atas keterlambatan pembayaran iuran., , Mekanisme administrasi pendaftaran bayi baru lahir sebagai peserta JKN-KIS mengacu pada ketentuan masing-masing jenis kepesertaan yaitu:, , 1. Peserta PBI Jaminan Kesehatan, Bayi yang dilahirkan oleh Ibu Kandung yang terdaftar sebagai peserta PBI JK secara otomatis ditetapkan sebagai peserta PBI JK sesuai dengan ketentuan peraturan perundang-undangan yang berlaku., , Peserta dari penduduk yang di daftarkan oleh Pemerintah Daerah (PD Pemda), mengacu kepada Perjanjian Kerja Sama (PKS) antara BPJS Kesehatan dengan Pemerintah Daerah dan dilakukan melalui Dinas Kesehatan/ Dinas Sosial Kabupaten/ Kota., , Syarat dan Cara Pendaftaran Bayi Baru Lahir:, 1. Menunjukkan nomor JKN dan data kependudukan ibu;, 2. Surat keterangan kelahiran dari Bidan/RS/Fasilitas Kesehatan atau tenaga penolong persalinan., , 2. Peserta PPU, Bayi baru lahir anak pertama sampai dengan ketiga dapat didaftarkan setelah bayi dilahirkan dan kepesertaannya langsung aktif mengacu pada status keaktifan orang tua PPU. Pendaftaran bisa dilakukan secara kolektif melalui Instansi/ Badan Usaha., Syarat dan Cara Pendaftaran Bayi Baru Lahir anak pertama sampai dengan ketiga:, 1. Menunjukkan nomor JKN dan data kependudukan ibu;, 2. Surat keterangan kelahiran dari Bidan/RS/Fasilitas Kesehatan atau tenaga penolong persalinan;, 3. Bayi baru lahir yang berusia lebih dari 3 bulan wajib memiliki NIK yang terdaftar pada Dukcapil., , 3. Peserta PBPU & BP, Bayi baru lahir peserta PBPU dan BP dapat didaftarkan dengan syarat:, 1. Menunjukkan nomor JKN dan data kependudukan ibu;, 2. Surat keterangan kelahiran dari Bidan/RS/Fasilitas Kesehatan atau tenaga penolong persalinan;, 3. Jika peserta belum melakukan autodebit tabungan dilengkapi dengan Buku rekening tabungan BNI, BRI, BTN, Mandiri dan BCA (dapat menggunakan rekening tabungan Kepala Keluarga/Anggota Keluarga dalam Kartu Keluarga/Penanggung);, 4. Melakukan perubahan data bayi selambat- lambatnya 3 (tiga) bulan setelah kelahiran yang meliputi nama, tanggal lahir, jenis kelamin, dan NIK.
# ==================================================
#
# ==================================================
# Pertanyaan: Dimana kontak kantor BPJS Kesehatan ?
# Maaf, saya tidak memiliki informasi mengenai kontak kantor BPJS Kesehatan dalam dokumen resmi yang tersedia. Untuk pertanyaan terkait alamat atau kontak kantor, Anda dapat mengunjungi situs resmi BPJS Kesehatan atau menghubungi layanan pelanggan mereka melalui saluran resmi yang tercantum di website.
#
# Mohon maaf atas ketidaknyamanannya. Jika ada pertanyaan lain terkait layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile, saya dengan senang hati akan membantu.
#
# ACTUAL DATA: Kantor Pusat BPJS Kesehatan, Jl. Letjen Suprapto Kav. 20 No.14, Jakarta Pusat 10510, Telp. 021 421 2938, , Care Center 165
# ==================================================
#
# ==================================================
# Pertanyaan: Apa itu GRC ?
# Maaf, saya tidak memiliki informasi resmi terkait istilah "GRC" dalam konteks layanan BPJS Kesehatan atau BPJS Ketenagakerjaan berdasarkan dokumen FAQ yang tersedia.
#
# Untuk pertanyaan lebih lanjut, Anda dapat mengunjungi situs resmi BPJS Kesehatan atau BPJS Ketenagakerjaan.
#
# Saya dengan senang hati membantu jika Anda memiliki pertanyaan lain terkait layanan BPJS.
#
# ACTUAL DATA: Governance, Risk, and Compliance (GRC) adalah pendekatan terpadu dan holistik terhadap organisasi untuk memastikan suatu organisasi bertindak secara etis dan sesuai dengan selera risiko, kebijakan internal, dan peraturan eksternal melalui penyelarasan strategi, proses, teknologi dan manusia, sehingga meningkatkan efisiensi dan efektivitas., , Penerapan GRC BPJS Kesehatan dilaksanakan merujuk pada penerapan Tata Kelola melalui pemenuhan prinsip Tata Kelola yang Baik dengan didukung budaya organisasi dan teknologi informasi yang memadai dalam rangka mendukung pencapaian tujuan organisasi
# ==================================================
#
# ==================================================
# Pertanyaan: Cara Membayar Iuran
# Berikut adalah cara membayar iuran BPJS Kesehatan sesuai prosedur resmi:
#
# 1. Pembayaran melalui Bank/Kantor Pos
#    • Kunjungi bank/pos mitra BPJS Kesehatan (contoh: BRI, BNI, Mandiri, atau kantor pos terdekat).
#    • Berikan nomor virtual account (VA) atau nomor peserta BPJS Kesehatan.
#    • Lakukan pembayaran sesuai nominal iuran yang tertera.
#
# 2. Pembayaran via ATM
#    • Masukkan kartu ATM dan pilih menu Pembayaran/Pembelian.
#    • Pilih BPJS Kesehatan atau Virtual Account.
#    • Masukkan nomor VA/nomor peserta.
#    • Konfirmasi nominal dan selesaikan transaksi.
#
# 3. Pembayaran melalui Aplikasi JKN Mobile
#    • Buka aplikasi JKN Mobile dan login.
#    • Pilih menu Pembayaran Iuran.
#    • Ikuti petunjuk untuk menyelesaikan pembayaran.
#
# 4. Pembayaran Otomatis (Auto-debit)
#    • Daftarkan akun bank Anda untuk auto-debit melalui mitra bank yang bekerja sama dengan BPJS Kesehatan.
#
# Pastikan pembayaran dilakukan sebelum tanggal jatuh tempo untuk menghindari denda atau pemutusan layanan.
#
# Jika membutuhkan bantuan lebih lanjut, silakan hubungi kontak resmi BPJS Kesehatan yang tersedia di website atau aplikasi JKN Mobile.
#
# ACTUAL DATA: Pembayaran iuran bagi peserta dapat dilakukan dengan tahapan sebagai berikut I. Peserta dan calon peserta PBPU Kelas I dan II wajib menggunakan fasilitas pembayaran auto debit banknon bank. II. Peserta melakukan registrasi autodebet melalui a. Kantor BPJS Kesehatan dengan mengisi form autodebit yang tersedia dengan melengkapi persyaratan pendaftaran berupa Fotocopy Kartu KeluargaKTP dan Buku Rekening b. Kanal Online seperti Mobile JKN Website BPJS Kesehatan Kanal Bank Aplikasi E-Commerce USSD III. Iuran pertama peserta akan otomatis terdebit pada periode tanggal 5 atau tanggal 20 setiap bulannya IV. Untuk kelancaran proses pendaftaran Autodebit pada Bank Pastikan Nomor Telepon yang digunakan benar atau sesuai dengan Nomoor Telepon yang digunakan saat pembukaan rekening di Bank untuk menerima Pin OTP dan pastikan memiliki saldo pulsa.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan ?
# Berikut adalah layanan BPJS Kesehatan yang dapat dimanfaatkan oleh peserta:
#
# 1. Pelayanan Kesehatan Tingkat Pertama (FKTP)
#    • Puskesmas
#    • Klinik (Pemerintah/Swasta)
#    • Dokter Praktek Mandiri
#    • Dokter Gigi Praktek Mandiri
#    • Fasilitas Kesehatan Tingkat Pertama lainnya yang bekerja sama dengan BPJS Kesehatan
#
# 2. Pelayanan Kesehatan Rujukan Tingkat Lanjutan (FKRTL)
#    • Rumah Sakit (Pemerintah/Swasta)
#    • Klinik Utama atau Spesialis
#    • Fasilitas kesehatan lanjutan lainnya yang bekerja sama dengan BPJS Kesehatan
#
# 3. Pelayanan Darurat
#    • Penanganan gawat darurat di semua fasilitas kesehatan, termasuk yang tidak bekerja sama dengan BPJS Kesehatan (dengan ketentuan tertentu).
#
# 4. Program Manajemen Penyakit Kronis (Prolanis)
#    • Layanan khusus untuk peserta dengan penyakit kronis seperti diabetes, hipertensi, dll.
#
# 5. Pelayanan Kesehatan Lainnya
#    • Persalinan
#    • Imunisasi dasar
#    • Keluarga Berencana
#    • Skrining kesehatan tertentu
#
# Pastikan untuk membawa kartu peserta dan memenuhi prosedur yang berlaku saat mengakses layanan.
#
# ACTUAL DATA: - Pelayanan Kesehatan Tingkat Pertama, Pelayanan Kesehatan Tingkat Pertama adalah pelayanan kesehatan perorangan yang bersifat non spesialistik (primer) meliputi pelayanan rawat jalan dan rawat inap yang diberikan oleh Fasilitas Kesehatan Tingkat Pertama (FKTP) :, - Puskesmas atau yang setara, - Praktik Mandiri Dokter, - Praktik Mandiri Dokter Gigi, - Klinik pratama atau yang setara, termasuk Fasilitas Kesehatan Tingkat Pertama (FKTP) milik TNI/Polri, - Rumah Sakit Kelas D Pratama atau yang setara, - Fasilitas kesehatan penunjang seperti apotek dan laboratorium., , - Rawat Jalan Tingkat Pertama, Merupakan pelayanan kesehatan perorangan yang bersifat non spesialistik yang dilaksanakan pada FKTP untuk keperluan observasi, diagnosis, pengobatan, dan/atau pelayanan kesehatan lainnya., Jenis pelayanan RJTP meliputi: administrasi pelayanan, termasuk biaya administrasi pendaftaran peserta untuk berobat, penyediaan, dan pemberian surat rujukan ke FKRTL untuk penyakit yang tidak dapat ditangani di FKTP, pelayanan promotif dan preventif perorangan, meliputi kegiatan penyuluhan kesehatan perorangan, imunisasi rutin, keluarga berencana, skrining riwayat kesehatan dan pelayanan penapisan atau skrining kesehatan tertentu, dan pelayanan Program Pengelolaan Penyakit Kronis, - Pemeriksaan, pengobatan, dan konsultasi medis, - Pemeriksaan ibu hamil, nifas, ibu menyusui, bayi dan anak balita, - Tindakan medis non spesialistik, baik operatif maupun non operatif, - Pelayanan obat, alat kesehatan, dan bahan medis habis pakai, - Pemeriksaan penunjang diagnostik laboratorium tingkat pratama, - Pelayanan Program Rujuk Balik, , - Rawat Inap Tingkat Pertama, Manfaat yang ditanggung:, 1. Pendaftaran dan administrasi, 2. Akomodasi rawat inap, 3. Pemeriksaan, pengobatan dan konsultasi medis, 4. Tindakan medis non spesialistik, baik operatif maupun non operatif, 5. Pelayanan kebidanan, ibu, bayi dan balita meliputi : , - Persalinan pervaginam bukan risiko tinggi, - Persalinan dengan komplikasi dan/atau penyulit pervaginam bagi Puskesmas PONED (Pelayanan Obstetri Neonatus Emergensi Dasar), - Pertolongan neonatal dengan komplikasi, 6. Pelayanan obat dan bahan medis habis pakai, 7. Pemeriksaan penunjang diagnostik laboratorium tingkat pratama., , - Pelayanan Kesehatan Rujukan Tingkat Lanjutan, Pelayanan Kesehatan Rujukan Tingkat Lanjutan adalah upaya pelayanan kesehatan perorangan yang bersifat spesialistik atau sub spesialistik yang meliputi rawat jalan tingkat lanjutan, rawat inap tingkat lanjutan, dan rawat inap di ruang perawatan khusus, yang diberikan oleh:, - Klinik utama atau yang setara., - Rumah Sakit Umum baik milik Pemerintah maupun Swasta, - Rumah Sakit Khusus, - Faskes Penunjang: Apotik, Optik dan Laboratorium, , - Rawat Jalan Tingkat Lanjut, Manfaat yang ditanggung :, 1. Administrasi pelayanan, 2. Pemeriksaan, pengobatan, dan konsultasi medis dasar yang dilakukan di unit gawat darurat, 3. Pemeriksaan, pengobatan, dan konsultasi spesialistik, 4. Tindakan medis spesialistik, baik bedah maupun non bedah sesuai dengan indikasi medis, 5. Pelayanan obat, alat kesehatan dan bahan medis habis pakai, 6. Pelayanan penunjang diagnostik lanjutan (laboratorium, radiologi dan penunjang diagnostik lainnya) sesuai dengan indikasi medis, 7. Rehabilitasi medis, 8. Pelayanan darah., , - Rawat Inap Tingkat Lanjut, Manfaat yang ditanggung, 1. Perawatan inap non intensif, 2. Perawatan inap intensif (ICU, ICCU, NICU, PICU).
# ==================================================
#
# ==================================================
# Pertanyaan: Kapan pembayaran iuran paling lambat ?
# Berdasarkan ketentuan BPJS Kesehatan, pembayaran iuran paling lambat dilakukan pada tanggal 10 setiap bulannya. Jika melebihi batas waktu tersebut, peserta dikenakan denda keterlambatan sesuai peraturan yang berlaku.
#
# Untuk informasi lebih lanjut, Anda dapat memeriksa ketentuan pembayaran di website resmi BPJS Kesehatan atau aplikasi JKN Mobile.
#
# ACTUAL DATA: Pembayaran iuran paling lambat tanggal 10 (sepuluh) setiap bulan
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana komitmen BPJS Kesehatan terkait gratifikasi ?
# Maaf, saya tidak memiliki informasi spesifik terkait komitmen BPJS Kesehatan mengenai gratifikasi dalam dokumen FAQ resmi yang tersedia.
#
# Untuk pertanyaan terkait kebijakan atau regulasi internal BPJS Kesehatan, Anda dapat menghubungi pihak resmi BPJS Kesehatan melalui saluran komunikasi yang tercantum di website resmi BPJS Kesehatan.
#
# Terima kasih.
#
# ACTUAL DATA: Dalam rangka penyelenggaraan tata kelola yang baik bebas dari korupsi, kolusi dan nepotisme di lingkungan BPJS Kesehatan. Duta BPJS Kesehatan dilarang menerima pemberian dalam bentuk apapun yang berhubungan dengan jabatannya. Pengendalian Gratifikasi di Lingkungan BPJS Kesehatan diatur dalam Peraturan Direksi yang menekankan terkait:, , 1. Pemahaman Gratifikasi, 2. Gratifikasi yang Wajib Dilaporkan dan Tidak Wajib Dilaporkan, 3. Pelaporan, Penetapan Status Gratifikasi dan Tindak Lanjut Pelaporan, 4. Unit Pengendalian Gratifikasi Terkait dengan pelaporan gratifikasi dapat melalui Unit Pengendalian Gratifikasi email: upg@bpjs-kesehatan.go.id
# ==================================================

# %% [markdown]
# Total pertanyaan sesuai dataset : 25
#
# Pertanyaan terjawab             : 16
#
# Pertanyaan tidak terjawab       : 9

# %% [markdown]
# Pertanyaan tidak terjawab:
# 1. Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# 2. Jika anggota baru di JMO, apakah harus mendaftar di MotionPay?
# 3. Apakah itu Promo?
# 4. Apakah itu MotionPay?
# 5. Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# 6. Apakah aplikasi Electronic Payment System (EPS)?
# 7. Dimana kontak kantor BPJS Kesehatan ?
# 8. Apa itu GRC ?
# 9. Bagaimana komitmen BPJS Kesehatan terkait gratifikasi ?
#
# Pertanyaan yang tidak dapat di jawab mayoritas adalah pertanyaan dari Ketenagakerjaan dengan category E-CHANNEL, dan sub-kategori JMO.
#
# Beberapa asumsi kenapa pertanyaan tersebut tidak dapat di jawab:
# 1. Pertanyaan tidak begitu jelas seperti promo, motionplay yang diartikan oleh bot sebagai di luar konteks BPJS, sehingga Deepseek tidak memberikan informasi, akan di coba improve pada promptnya.
# 2. Size embeding 300 dan overlap 50 kemungkinan terlalu kecil sehingga kurang membuat model mengerti reasoning pertanyaan dan jawaban.
# 3. Treshold similarity sebesar 70%, akan di coba untuk di tingkatkan.

# %% [markdown]
# ## Test Case 2 Pertanyaan Diluar Dataset

# %%
# UJI COBA 2: Pertanyaan di Luar Konteks
questions = [
    "Apa itu Allo Bank?",
    "Bagaimana cara mengajukan KPR?",
    "Siapa penemu listrik?",
    "Apa saja manfaat dari olahraga?",
    "Bagaimana cara membuat kue?",
    "Jelaskan apa itu Quantum Computing?",
    "Apa yang dimaksud dengan Machine Learning?",
    "Gimana cara buat foto HD dengan AI?",
    "Apa itu teknologi blockchain?",
    "Apa itu teknologi quantum?",
    "Apa kopi paling enak saat ini?",
    "Sebutkan Sepatu lari paling enak",
    "Kapan Indonesia Merdeka?",
    "Dimana kantor urusan agama terdekat",
    "Jelaskan tentang skema piala dunia?",
    "Siapa pencetak gol terbanyak piala dunia 2022?",
    "Jumlah total trofi Liverpool berapa?",
    "Hitung luas Kota Surabaya",
    "Dimana tempat syuting film laskar Pelangi?",
    "Dimana bom atom amerika saat perang dunia kedua dibuat?",
    "Bagaimana cara membedakan biji kopi?",
    "Jembatan merah ada Dimana?",
    "Siapa presiden Indonesia pertama?",
    "Siapa penemu alat musik gitar?",
    "Hitung luas lapangan bola."
    ]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    result = qa.invoke({"query": q})
    print(clean_answer(result['result']))
    print(f"\nACTUAL DATA: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: Apa itu Allo Bank?
# Maaf, pertanyaan Anda tentang "Allo Bank" tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu pertanyaan yang berkaitan dengan ketiga layanan tersebut sesuai dokumen resmi.
#
# Jika Anda memiliki pertanyaan seputar BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara mengajukan KPR?
# Maaf, pertanyaan Anda mengenai cara mengajukan KPR (Kredit Pemilikan Rumah) tidak termasuk dalam lingkup layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Untuk informasi terkait KPR, disarankan menghubungi pihak bank atau lembaga keuangan terkait.
#
# Jika Anda memiliki pertanyaan seputar layanan BPJS, saya dengan senang hati akan membantu.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapa penemu listrik?
# Mohon maaf, saya tidak dapat memberikan informasi tersebut karena pertanyaan Anda berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Saya siap membantu jika Anda memiliki pertanyaan seputar:
# • Prosedur pendaftaran BPJS Kesehatan/Ketenagakerjaan
# • Fitur Aplikasi JKN Mobile
# • Klaim manfaat program BPJS
#
# Silakan bertanya kembali dengan detail kebutuhan Anda.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa saja manfaat dari olahraga?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan seputar ketiga layanan tersebut sesuai informasi resmi yang tersedia.
#
# Jika Anda memiliki pertanyaan terkait manfaat program BPJS, prosedur pendaftaran, klaim, atau fitur aplikasi JKN Mobile, saya dengan senang hati akan membantu.
#
# Contoh pertanyaan yang bisa saya jawab:
# • Bagaimana cara daftar BPJS Kesehatan online?
# • Apa manfaat program JKK BPJS Ketenagakerjaan?
# • Cara cek saldo di aplikasi JKN Mobile?
#
# Silakan ajukan pertanyaan Anda kembali dengan detail yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara membuat kue?
# Maaf, pertanyaan Anda tidak relevan dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Saya hanya dapat membantu informasi terkait ketiga layanan tersebut sesuai dokumen resmi BPJS.
#
# Jika Anda memiliki pertanyaan seputar BPJS, silakan ajukan pertanyaan yang lebih spesifik. Contoh:
# • Cara daftar BPJS Kesehatan
# • Prosedur klaim BPJS Ketenagakerjaan
# • Fitur-fitur di Aplikasi JKN Mobile
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Jelaskan apa itu Quantum Computing?
# Maaf, pertanyaan Anda tidak relevan dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Saya hanya dapat membantu informasi terkait ketiga layanan tersebut sesuai dokumen resmi BPJS.
#
# Jika Anda memiliki pertanyaan seputar BPJS, silakan ajukan pertanyaan yang lebih spesifik. Contoh:
# • Cara daftar BPJS Kesehatan
# • Prosedur klaim BPJS Ketenagakerjaan
# • Fitur-fitur di Aplikasi JKN Mobile
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa yang dimaksud dengan Machine Learning?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan seputar ketiga layanan tersebut sesuai dengan informasi resmi yang tersedia.
#
# Jika Anda memiliki pertanyaan terkait BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Gimana cara buat foto HD dengan AI?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan seputar ketiga layanan tersebut sesuai dengan informasi resmi yang tersedia.
#
# Jika Anda memiliki pertanyaan terkait BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa itu teknologi blockchain?
# Maaf, pertanyaan Anda tentang teknologi blockchain tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu pertanyaan yang berkaitan dengan:
# • Layanan BPJS Kesehatan
# • FAQ BPJS Ketenagakerjaan
# • Panduan Aplikasi JKN Mobile
#
# Silakan ajukan pertanyaan yang sesuai dengan konteks di atas. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa itu teknologi quantum?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan seputar ketiga layanan tersebut sesuai dokumen resmi yang tersedia.
#
# Jika Anda memiliki pertanyaan terkait BPJS, silakan ajukan pertanyaan yang lebih spesifik. Contoh:
# • Cara daftar BPJS Kesehatan
# • Prosedur klaim BPJS Ketenagakerjaan
# • Fitur-fitur di Aplikasi JKN Mobile
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa kopi paling enak saat ini?
# Maaf, saya tidak memiliki informasi terkait kopi karena pertanyaan tersebut berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Silakan bertanya seputar:
# • Prosedur pendaftaran BPJS Kesehatan/Ketenagakerjaan
# • Cara menggunakan fitur Aplikasi JKN Mobile
# • Klaim manfaat program BPJS
# atau layanan lain yang tercantum dalam FAQ resmi BPJS.
#
# Saya siap membantu! 😊
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Sebutkan Sepatu lari paling enak
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan seputar layanan resmi BPJS.
#
# Jika Anda memiliki pertanyaan terkait program, prosedur, atau fitur BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Kapan Indonesia Merdeka?
# Maaf, saya tidak dapat memberikan informasi tersebut karena pertanyaan Anda berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Silakan bertanya seputar layanan BPJS yang tersedia, seperti:
# • Prosedur pendaftaran BPJS Kesehatan
# • Cara klaim manfaat BPJS Ketenagakerjaan
# • Panduan penggunaan Aplikasi JKN Mobile
#
# Saya dengan senang hati akan membantu.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Dimana kantor urusan agama terdekat
# Maaf, saya tidak memiliki informasi mengenai lokasi Kantor Urusan Agama terdekat karena pertanyaan tersebut di luar cakupan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, dan Aplikasi JKN Mobile.
#
# Untuk pertanyaan terkait layanan BPJS, saya dengan senang hati membantu Anda.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Jelaskan tentang skema piala dunia?
# Maaf, saya tidak memiliki informasi terkait skema Piala Dunia karena pertanyaan tersebut berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Saya hanya dapat membantu pertanyaan yang berkaitan dengan:
# • Layanan BPJS Kesehatan
# • FAQ BPJS Ketenagakerjaan
# • FAQ Aplikasi JKN Mobile
#
# Silakan ajukan pertanyaan terkait layanan tersebut agar saya dapat memberikan informasi yang akurat. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapa pencetak gol terbanyak piala dunia 2022?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual Resmi BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan seputar ketiga layanan tersebut sesuai informasi resmi yang tersedia.
#
# Jika Anda memiliki pertanyaan terkait BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Jumlah total trofi Liverpool berapa?
# Maaf, saya tidak memiliki informasi tersebut karena pertanyaan Anda berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Saya hanya dapat membantu pertanyaan terkait:
# • Layanan BPJS Kesehatan
# • FAQ BPJS Ketenagakerjaan
# • Panduan Aplikasi JKN Mobile
#
# Silakan ajukan pertanyaan yang sesuai dengan layanan kami. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Hitung luas Kota Surabaya
# Maaf, saya tidak dapat membantu menghitung luas Kota Surabaya karena pertanyaan tersebut tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Silakan ajukan pertanyaan seputar layanan BPJS yang Anda butuhkan, seperti:
# • Prosedur pendaftaran BPJS Kesehatan
# • Cara klaim manfaat BPJS Ketenagakerjaan
# • Fitur-fitur dalam Aplikasi JKN Mobile
#
# Saya dengan senang hati akan membantu.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Dimana tempat syuting film laskar Pelangi?
# Maaf, saya tidak memiliki informasi terkait lokasi syuting film Laskar Pelangi karena pertanyaan tersebut berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, dan Aplikasi JKN Mobile.
#
# Jika Anda memiliki pertanyaan seputar layanan BPJS, saya dengan senang hati akan membantu. Contoh pertanyaan yang dapat saya jawab:
# • Cara daftar BPJS Kesehatan
# • Prosedur klaim BPJS Ketenagakerjaan
# • Fitur-fitur di Aplikasi JKN Mobile
#
# Silakan ajukan pertanyaan terkait layanan BPJS. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Dimana bom atom amerika saat perang dunia kedua dibuat?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual Resmi BPJS Indonesia, saya hanya dapat membantu pertanyaan seputar layanan dan prosedur yang berkaitan dengan BPJS.
#
# Jika Anda memiliki pertanyaan terkait BPJS, silakan ajukan pertanyaan yang lebih spesifik. Contoh:
# • Cara daftar BPJS Kesehatan
# • Prosedur klaim BPJS Ketenagakerjaan
# • Fitur-fitur di Aplikasi JKN Mobile
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Bagaimana cara membedakan biji kopi?
# Mohon maaf, pertanyaan Anda tidak relevan dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Saya hanya dapat membantu terkait informasi resmi dari ketiga layanan tersebut.
#
# Jika Anda memiliki pertanyaan seputar BPJS, silakan ajukan pertanyaan yang lebih spesifik. Contoh:
# • Cara daftar BPJS Kesehatan
# • Prosedur klaim BPJS Ketenagakerjaan
# • Fitur-fitur di Aplikasi JKN Mobile
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Jembatan merah ada Dimana?
# Maaf, saya tidak memiliki informasi terkait lokasi Jembatan Merah karena pertanyaan tersebut berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Silakan bertanya kembali mengenai layanan BPJS yang dapat saya bantu, seperti:
# • Pendaftaran peserta
# • Pembayaran iuran
# • Manfaat program
# • Penggunaan aplikasi JKN Mobile
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapa presiden Indonesia pertama?
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS, saya hanya dapat membantu menjawab pertanyaan seputar layanan kami sesuai dokumen resmi.
#
# Jika Anda memiliki pertanyaan terkait BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapa penemu alat musik gitar?
# Mohon maaf, saya tidak dapat memberikan informasi tersebut karena pertanyaan Anda berada di luar konteks layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Saya hanya dapat membantu pertanyaan terkait:
# • Prosedur layanan BPJS Kesehatan
# • FAQ BPJS Ketenagakerjaan
# • Panduan penggunaan Aplikasi JKN Mobile
#
# Silakan ajukan pertanyaan yang sesuai dengan layanan kami. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Hitung luas lapangan bola.
# Maaf, saya tidak dapat membantu menghitung luas lapangan bola karena pertanyaan tersebut tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Silakan ajukan pertanyaan seputar layanan BPJS yang Anda butuhkan, seperti:
# • Prosedur pendaftaran BPJS Kesehatan
# • Cara klaim manfaat BPJS Ketenagakerjaan
# • Fitur-fitur dalam Aplikasi JKN Mobile
#
# Saya siap membantu dengan informasi resmi dari BPJS Indonesia.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================

# %% [markdown]
# Total pertanyaan diluat dataset : 25
#
# Pertanyaan terjawab             : 0
#
# Pertanyaan tidak terjawab       : 25

# %% [markdown]
# Peforma model sangat baik untuk tidak menjawab pertanyaan yang tidak relevan dengan BPJS, treshold 70% dianggap sudah cukup untuk model tidak menjawab pertanyaan tidak relevan

# %% [markdown]
# ## Test Case 3 Pertanyaan Tidak Lengkap/Typo

# %%
# UJI COBA 3: Pertanyaan Masih dalam Konteks namun terdapat kesalahan input
questions = [
   "Aph itu BPJS Ketenagakerajaan?",
    "Apa sajak program BPJS Ketenagakerjaan?",
    "Siapakah yang dimaksud peserta BPJS Ketenagakerajaan?",
    "Apakh yang dimaksud dengan PHK?",
    "Apakah pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP?",
    "Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?", 
    "Gimana jika lupa PIN EPS?",
    "Apakah itu Perumahan Pekerja?",
    "Dokumen apa sajakah persyaratan mengajukan JHT bagi PMI yang berpindah menjadi Warga Negara Asing?",
    "Kapan BSU tahun 2025 dibagikan?",
    "Dimana obat batuk pertama kali ditemukan",
    "Jika flu sebaiknya minum obat herbal apa",
    "Sopo peserta BPJS ketenagakerjaan",
    "Sejak tanggal berapa pembayaran iuran paling lambat ?",
    "Jika anggota baru di JMO, apakah harus mendaftar di MotionIme?",
    "Apakah itu ShoopePay?",
    "Apa perbedaan program Jaminan Dari Tua (JHT) dan Jaminan Pensiun (JP)?",
    "Gimana pembayaran iuran?",
    "Tanggal pembayaran iuran paling lambat ?",
    "Promo apa sajak yang tersedia pada aplikasi Jamsostek Mobile (JMO)?"
]

for q in questions:
    print(f"\n{'='*50}")
    print(f"Pertanyaan: {q}")
    result = qa.invoke({"query": q})
    print(clean_answer(result['result']))
    print(f"\nACTUAL DATA: {answer_from_doc(q)}")
    print(f"{'='*50}")
# Out:
# ==================================================
# Pertanyaan: Aph itu BPJS Ketenagakerajaan?
# BPJS Ketenagakerjaan adalah program perlindungan sosial bagi tenaga kerja yang diselenggarakan oleh Badan Penyelenggara Jaminan Sosial (BPJS) Ketenagakerjaan. Program ini memberikan manfaat berupa:
#
# • Jaminan Kecelakaan Kerja (JKK)
# • Jaminan Hari Tua (JHT)
# • Jaminan Pensiun (JP)
# • Jaminan Kematian (JKm)
#
# Informasi lebih lanjut dapat dilihat di situs resmi BPJS Ketenagakerjaan.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa sajak program BPJS Ketenagakerjaan?
# Berikut adalah program-program BPJS Ketenagakerjaan berdasarkan informasi resmi:
#
# 1. Jaminan Kecelakaan Kerja (JKK)
#    • Memberikan perlindungan atas risiko kecelakaan kerja atau penyakit akibat kerja.
#
# 2. Jaminan Kematian (JKM)
#    • Memberikan manfaat kepada ahli waris jika peserta meninggal dunia (bukan akibat kecelakaan kerja).
#
# 3. Jaminan Hari Tua (JHT)
#    • Memberikan manfaat berupa tabungan yang dapat dicairkan saat peserta memenuhi syarat (misalnya pensiun atau berhenti bekerja).
#
# 4. Jaminan Pensiun (JP)
#    • Memberikan manfaat pensiun bulanan setelah peserta mencapai usia pensiun atau memenuhi ketentuan lainnya.
#
# 5. Jaminan Kehilangan Pekerjaan (JKP)
#    • Memberikan bantuan sementara berupa tunjangan dan pelatihan bagi peserta yang kehilangan pekerjaan.
#
# Semua program di atas diatur sesuai ketentuan undang-undang dan peraturan BPJS Ketenagakerjaan. Untuk detail lebih lanjut, Anda dapat mengunjungi situs resmi BPJS Ketenagakerjaan.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Siapakah yang dimaksud peserta BPJS Ketenagakerajaan?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, yang dimaksud dengan peserta adalah:
#
# 1. Pekerja Penerima Upah (PPU):
#    • Pegawai/karyawan perusahaan.
#    • PNS, TNI/POLRI, dan pejabat negara.
#    • Pekerja dengan perjanjian kerja waktu tertentu (PKWT).
#
# 2. Pekerja Bukan Penerima Upah (PBPU):
#    • Pekerja mandiri (wiraswasta, freelancer, dll.).
#    • Pekerja di luar hubungan kerja (misalnya: petani, nelayan).
#
# 3. Peserta Bukan Pekerja (BP):
#    • Individu yang membayar iuran secara mandiri (misalnya: ibu rumah tangga, pelajar).
#
# Catatan: Kategori peserta dapat berbeda berdasarkan program manfaat (JKK, JKM, JHT, atau JP).
#
# Jika Anda memerlukan penjelasan lebih spesifik terkait kategori tertentu, silakan sampaikan pertanyaan lebih detail.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakh yang dimaksud dengan PHK?
# PHK adalah singkatan dari Pemutusan Hubungan Kerja, yaitu pengakhiran hubungan kerja antara perusahaan dan pekerja karena suatu alasan tertentu.
#
# Informasi lebih lanjut terkait PHK dapat dilihat pada ketentuan yang berlaku dalam peraturan ketenagakerjaan atau melalui layanan resmi BPJS Ketenagakerjaan.
#
# Jika Anda memerlukan bantuan lebih lanjut, silakan hubungi layanan pelanggan BPJS Ketenagakerjaan.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, Buruh Harian Lepas (BHL) termasuk kategori pekerja yang dapat mengikuti program Jaminan Kehilangan Pekerjaan (JKP) dengan ketentuan sebagai berikut:
#
# 1. Syarat Peserta:
#    • Terdaftar sebagai peserta BPJS Ketenagakerjaan.
#    • Memiliki masa kepesertaan minimal 12 bulan dalam 24 bulan terakhir sebelum kehilangan pekerjaan.
#
# 2. Prosedur Pendaftaran:
#    • Pemberi kerja (misalnya penyedia lapangan kerja) mendaftarkan BHL melalui sistem BPJS Ketenagakerjaan.
#
# Jika BHL memenuhi persyaratan di atas, mereka berhak mengajukan klaim JKP dengan melampirkan dokumen yang diperlukan.
#
# Untuk informasi lebih lanjut, silakan merujuk ke FAQ BPJS Ketenagakerjaan atau hubungi kontak resmi BPJS Ketenagakerjaan yang tersedia di situs web resmi.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, berikut langkah yang dapat dilakukan jika pembayaran iuran BPU (BP Jaminan Pensiun) belum memperbarui masa perlindungan/saldo JHT:
#
# 1. Pastikan bukti pembayaran valid
#    • Cek kembali bukti pembayaran (contoh: kode billing, struk pembayaran) untuk memastikan transaksi berhasil.
#
# 2. Verifikasi waktu proses
#    • Proses pembaruan saldo/masa perlindungan membutuhkan waktu maksimal 3 hari kerja setelah pembayaran. Jika belum lewat waktu tersebut, harap menunggu.
#
# 3. Hubungi layanan BPJS Ketenagakerjaan
#    • Jika setelah 3 hari kerja belum ada perubahan, silakan hubungi:
#      - Kontak resmi BPJS Ketenagakerjaan (sesuai informasi di website/FAQ)
#      - Sertakan bukti pembayaran untuk verifikasi lebih lanjut.
#
# 4. Periksa data peserta
#    • Pastikan nomor identitas (NPWP/NIK) dan nomor BPJS Ketenagakerjaan yang digunakan saat pembayaran sudah benar.
#
# Jika ada ketidaksesuaian lebih lanjut, tim BPJS Ketenagakerjaan akan membantu proses pengecekan.
#
# (Informasi berdasarkan prosedur standar BPJS Ketenagakerjaan)
#
# ACTUAL DATA: Peserta dapat menunjukkan tanda bukti pembayaran dari kanal pembayaran iuran dimana Peserta melakukan transaksi pembayaran iuran. Selanjutnya laporan akan ditindaklanjuti segera oleh tim BPJS Ketenagakerjaan.
# ==================================================
#
# ==================================================
# Pertanyaan: Gimana jika lupa PIN EPS?
# Jika lupa PIN EPS BPJS Ketenagakerjaan, berikut langkah untuk meresetnya:
#
# 1. Kunjungi kantor BPJS Ketenagakerjaan terdekat dengan membawa:
#    • Kartu Tanda Penduduk (KTP) asli.
#    • Kartu peserta BPJS Ketenagakerjaan (jika ada).
#
# 2. Isi formulir permohonan reset PIN EPS yang disediakan oleh petugas.
#
# 3. Verifikasi data oleh petugas untuk memastikan keabsahan permohonan.
#
# 4. PIN baru akan diberikan setelah proses verifikasi selesai.
#
# Pastikan untuk menghubungi kantor BPJS Ketenagakerjaan terlebih dahulu guna memastikan persyaratan tambahan (jika ada).
#
# (Prosedur berdasarkan kebijakan resmi BPJS Ketenagakerjaan)
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah itu Perumahan Pekerja?
# Maaf, saya tidak memiliki informasi resmi terkait "Perumahan Pekerja" dalam dokumen FAQ BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile.
#
# Untuk pertanyaan terkait program perumahan, Anda dapat menghubungi pihak terkait seperti Kementerian PUPR atau program perumahan yang disediakan oleh perusahaan tempat bekerja.
#
# Jika Anda memiliki pertanyaan seputar layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile, saya dengan senang hati akan membantu.
#
# ACTUAL DATA: Fitur pengajuan manfaat perumahan pekerja untuk fasilitas pembiayaan perumahan yang diberikan oleh BPJS Ketenagakerjaan kepada peserta program JHT.
# ==================================================
#
# ==================================================
# Pertanyaan: Dokumen apa sajakah persyaratan mengajukan JHT bagi PMI yang berpindah menjadi Warga Negara Asing?
# Berdasarkan informasi resmi BPJS Ketenagakerjaan, berikut persyaratan dokumen untuk mengajukan Jaminan Hari Tua (JHT) bagi Pekerja Migran Indonesia (PMI) yang berpindah menjadi Warga Negara Asing:
#
# 1. Surat Pernyataan dari PMI yang menyatakan telah pindah kewarganegaraan.
# 2. Fotokopi dokumen perubahan kewarganegaraan (misalnya: paspor asing atau surat naturalisasi).
# 3. Fotokopi dokumen identitas lama (KTP Indonesia/paspor Indonesia).
# 4. Fotokopi bukti kepesertaan BPJS Ketenagakerjaan (jika ada).
#
# Prosedur pengajuan dapat dilakukan melalui kantor BPJS Ketenagakerjaan terdekat atau melalui mitra resmi BPJS Ketenagakerjaan di luar negeri (jika tersedia).
#
# Jika ada dokumen tambahan yang diperlukan, pastikan untuk menghubungi layanan pelanggan BPJS Ketenagakerjaan terlebih dahulu.
#
# ACTUAL DATA: Peserta mengajukan permohonan pembayaran manfaat program JHT menggunakan formulir pengajuan manfaat dengan melampirkan persyaratan sebagai berikut:, Kartu Peserta BPJS Ketenagakerjaan; surat pindah kewarganegaraan dari instansi yang berwenang dan/atau bukti identitas sebagai warga negara asing; dan rekening tabungan atas nama PMI.
# ==================================================
#
# ==================================================
# Pertanyaan: Kapan BSU tahun 2025 dibagikan?
# Maaf, saya tidak memiliki informasi resmi terkait jadwal penyaluran Bantuan Subsidi Upah (BSU) tahun 2025. Untuk informasi terbaru dan akurat, Anda dapat memantau pengumuman resmi melalui:
# - Website BPJS Ketenagakerjaan
# - Aplikasi JKN Mobile
# - Kontak resmi BPJS Ketenagakerjaan
#
# Saya sarankan untuk mengecek sumber resmi tersebut secara berkala.
#
# (Jawaban mengacu pada aturan poin 3: Jika pertanyaan tidak tersedia dalam data, sampaikan secara sopan bahwa informasi tidak tersedia dan arahkan ke sumber resmi yang mungkin memiliki update terbaru.)
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Dimana obat batuk pertama kali ditemukan
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual Resmi BPJS Indonesia, saya hanya dapat membantu menjawab pertanyaan yang berkaitan dengan ketiga layanan tersebut sesuai dokumen resmi.
#
# Jika Anda memiliki pertanyaan seputar BPJS, silakan ajukan pertanyaan yang lebih spesifik. Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Jika flu sebaiknya minum obat herbal apa
# Maaf, pertanyaan Anda tidak terkait dengan layanan BPJS Kesehatan, BPJS Ketenagakerjaan, atau Aplikasi JKN Mobile. Sebagai Asisten Virtual BPJS Indonesia, saya hanya dapat membantu pertanyaan yang berkaitan dengan ketiga layanan tersebut sesuai dokumen resmi.
#
# Untuk konsultasi kesehatan atau rekomendasi pengobatan, disarankan menghubungi fasilitas kesehatan terdaftar atau dokter.
#
# Apabila Anda membutuhkan informasi terkait layanan BPJS, saya dengan senang hati membantu.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Sopo peserta BPJS ketenagakerjaan
# Maaf, saya tidak menemukan informasi terkait pertanyaan "Sopo peserta BPJS ketenagakerjaan" dalam dokumen resmi BPJS Ketenagakerjaan.
#
# Untuk informasi peserta BPJS Ketenagakerjaan, Anda dapat mengunjungi website resmi BPJS Ketenagakerjaan atau menghubungi layanan pelanggan mereka.
#
# Mohon pastikan pertanyaan menggunakan bahasa yang jelas dan sesuai konteks layanan BPJS.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Sejak tanggal berapa pembayaran iuran paling lambat ?
# Berdasarkan ketentuan BPJS Kesehatan, pembayaran iuran paling lambat dilakukan setiap tanggal 10 bulan berjalan.
#
# Contoh:
# - Iuran bulan Januari 2025 harus dibayar paling lambat tanggal 10 Januari 2025.
#
# Jika melebihi batas waktu tersebut, peserta dikenakan denda keterlambatan sesuai peraturan yang berlaku.
#
# Untuk informasi lebih lanjut, Anda dapat memeriksa ketentuan resmi di website BPJS Kesehatan atau aplikasi JKN Mobile.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Jika anggota baru di JMO, apakah harus mendaftar di MotionIme?
# Maaf, saya tidak memiliki informasi resmi terkait pertanyaan Anda tentang pendaftaran anggota baru di JMO melalui MotionIme. Untuk informasi yang akurat, silakan merujuk ke panduan resmi atau hubungi layanan pelanggan BPJS Kesehatan melalui saluran resmi yang tersedia.
#
# Terima kasih.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apakah itu ShoopePay?
# Maaf, saya tidak memiliki informasi resmi terkait "ShoopePay" dalam database BPJS Kesehatan atau BPJS Ketenagakerjaan.
#
# Untuk pertanyaan terkait layanan BPJS, Anda dapat menyampaikan pertanyaan yang lebih spesifik seperti:
# • Prosedur pendaftaran BPJS Kesehatan
# • Cara klaim manfaat BPJS Ketenagakerjaan
# • Fitur dalam aplikasi JKN Mobile
#
# Saya siap membantu dengan informasi resmi dari BPJS Indonesia.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Apa perbedaan program Jaminan Dari Tua (JHT) dan Jaminan Pensiun (JP)?
# Berikut perbedaan antara program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP) berdasarkan ketentuan BPJS Ketenagakerjaan:
#
# 1. Jaminan Hari Tua (JHT)
# • Manfaat: Memberikan dana tunai kepada peserta saat memasuki usia pensiun, meninggal dunia, atau mengalami cacat total tetap.
# • Sumber Iuran: Dibayarkan oleh pekerja dan pemberi kerja (kombinasi).
# • Waktu Pencairan: Dapat dicairkan saat peserta berusia 56 tahun, meninggal, atau mengalami cacat total.
#
# 2. Jaminan Pensiun (JP)
# • Manfaat: Memberikan penghasilan bulanan kepada peserta setelah mencapai usia pensiun (58 tahun) atau mengalami cacat total.
# • Sumber Iuran: Dibayarkan sepenuhnya oleh pemberi kerja.
# • Waktu Pencairan: Dimulai saat peserta memenuhi syarat usia pensiun atau kondisi cacat total.
#
# Perbedaan Utama:
# - JHT berbentuk dana tunai sekaligus, sedangkan JP berupa pembayaran rutin bulanan.
# - Iuran JHT bersifat akumulatif, sementara JP mengikuti skema tabungan pensiun.
#
# Informasi lebih detail dapat dilihat di FAQ BPJS Ketenagakerjaan atau website resmi BPJS Ketenagakerjaan.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Gimana pembayaran iuran?
# Berikut informasi prosedur pembayaran iuran BPJS Kesehatan berdasarkan sumber resmi:
#
# Cara Pembayaran Iuran BPJS Kesehatan:
# 1. Pembayaran Mandiri (Peserta Mandiri/Pekerja Bukan Penerima Upah):
#    • Bayar melalui ATM, mobile banking, internet banking, atau kantor pos.
#    • Gunakan kode pembayaran/nomor virtual account (VA) yang tertera di kartu peserta atau aplikasi JKN Mobile.
#
# 2. Pembayaran oleh Pemberi Kerja (Peserta Penerima Upah):
#    • Iuran dibayarkan oleh perusahaan/pemberi kerja melalui mekanisme pemotongan gaji.
#
# 3. Pembayaran via Aplikasi JKN Mobile:
#    • Buka menu "Pembayaran Iuran" di aplikasi.
#    • Pilih metode pembayaran (virtual account/dompet digital).
#
# Catatan:
# - Pastikan pembayaran dilakukan sebelum tanggal jatuh tempo untuk menghindari denda.
# - Cek status pembayaran melalui aplikasi JKN Mobile atau hubungi BPJS Kesehatan Contact Center.
#
# Jika Anda memerlukan detail lebih spesifik (misal: nominal iuran), silakan sebutkan jenis peserta (mandiri/PBU/PBPU) agar kami dapat memberikan informasi yang tepat.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Tanggal pembayaran iuran paling lambat ?
# Berdasarkan ketentuan BPJS Kesehatan, tanggal pembayaran iuran paling lambat adalah setiap tanggal 10 bulan berjalan.
#
# Contoh:
# - Iuran bulan Januari 2025 harus dibayar paling lambat tanggal 10 Januari 2025.
#
# Jika melebihi batas waktu tersebut, peserta dikenakan denda keterlambatan sesuai peraturan yang berlaku.
#
# Untuk informasi lebih lanjut, Anda dapat memeriksa tagihan atau menghubungi layanan resmi BPJS Kesehatan.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================
#
# ==================================================
# Pertanyaan: Promo apa sajak yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# Maaf, saat ini tidak ada informasi mengenai promo yang tersedia di Aplikasi JKN Mobile dalam dokumen resmi BPJS Kesehatan. Untuk informasi terbaru, Anda dapat memeriksa pengumuman resmi melalui website BPJS Kesehatan atau aplikasi JKN Mobile.
#
# Jika ada pertanyaan lain terkait layanan BPJS Kesehatan atau BPJS Ketenagakerjaan, saya dengan senang hati akan membantu.
#
# ACTUAL DATA: Tidak ada jawaban.
# ==================================================

# %% [markdown]
# Total pertanyaan salah tidak baku/typo : 20
#
# Pertanyaan terjawab             : 11
#
# Pertanyaan tidak terjawab       : 9

# %% [markdown]
# Pertanyaan yang tidak terjawab :
# 1. Apakah pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP?
# 2. Apakah itu Perumahan Pekerja?
# 3. Kapan BSU tahun 2025 dibagikan?
# 4. Dimana obat batuk pertama kali ditemukan
# 5. Jika flu sebaiknya minum obat herbal apa
# 6. Jika anggota baru di JMO, apakah harus mendaftar di MotionIme?
# 7. Apakah itu ShoopePay?
# 8. Promo apa sajak yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# 9. Sopo peserta BPJS ketenagakerjaan

# %% [markdown]
# Analisa:
# 1. Model dapat mengerti apabila terdapat kata yang tidak lengkap atau typo namun kesalahan kata tersebut tidak merujuk pada kata yang memiliki makna lain, seperti pertanyaan Aph itu BPJS Ketenagakerajaan?, typo Aph sangat dekat dengan Apa sehingga model mampu menjawab.
# 2. Pertanyaan yang memiliki makna berbeda seperti Apakah pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP?, dianggap model berada diluar konteks sehingga model tidak menjawab.
