# %%
# Import Library
import pandas as pd
import os
import re
from dotenv import load_dotenv
from langchain_ollama import OllamaEmbeddings
from langchain_mongodb import MongoDBAtlasVectorSearch
from pymongo import MongoClient
from langchain_ollama.llms import OllamaLLM
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA

# %%
#Load environment variables
load_dotenv(override=True)
MONGODB_URI = os.getenv("MONGODB_URI")

# %%
#initialize embeddings
embeddings=OllamaEmbeddings(model="mxbai-embed-large")

# %%
#Model configuration with llama
model= OllamaLLM(model="llama3.2",
                temperature=0,
                convert_system_message_to_human=True)

# %%
# MongoDB Connection
client = MongoClient(MONGODB_URI)
collection = client['finalproject_db']['faq_tb']
index_name = 'vector_index'

# %%
# Vector Store Configuration
vector_store = MongoDBAtlasVectorSearch(
    collection=collection,
    embedding=embeddings,
    index_name='vector_index'
)

# %%
# PROMPT BARU UNTUK BPJS
BPJS_PROMPT = PromptTemplate(
    input_variables=["context", "question"],
    template="""
    Anda adalah Asisten Digital Resmi BPJS Kesehatan dan BPJS Ketenagakerjaan.
    Tugas Anda sebagai Customer Service adalah menjawab pertanyaan peserta berdasarkan data FAQ resmi yang telah disediakan.

    Tanggung jawab utama:
    - Memberikan jawaban yang akurat dan informatif sesuai dengan kategori FAQ BPJS Kesehatan dan BPJS Ketenagakerjaan.
    - Menyampaikan informasi dengan bahasa yang profesional, jelas, dan mudah dipahami oleh seluruh lapisan masyarakat.
    - Memberikan panduan teknis atau prosedur (jika diperlukan) dalam format langkah-langkah yang berurutan atau poin-poin.
    - Menanggapi pertanyaan atau peserta dengan solusi yang relevan dari konteks FAQ yang tersedia.

    Aturan jawaban:
    1. Jawab hanya berdasarkan informasi yang tersedia dalam konteks FAQ resmi yang diberikan.
    2. Jika pertanyaan tidak relevan atau tidak tercakup dalam FAQ, jawab dengan sopan: "Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan."
    3. Jangan mengarang jawaban atau memberikan informasi di luar dokumen sumber.
    4. Jangan mencantumkan link eksternal atau informasi promosi di luar konteks.
    5. Gunakan format poin atau numerik bila menjelaskan prosedur atau langkah-langkah.

    Konteks resmi (dari FAQ):
    {context}

    Pertanyaan Peserta: {question}

    Jawaban Profesional:
    """
)

# %%
qa = RetrievalQA.from_chain_type(
    llm=model,
    chain_type="stuff",
    retriever=vector_store.as_retriever(
        search_type="similarity",
        search_kwargs={"k": 5, "score_treshold":0.85 
                       }  # Mengambil 5 dokumen teratas

    ),
    return_source_documents=True,
    chain_type_kwargs={"prompt": BPJS_PROMPT}
)
def clean_answer(raw_answer):
    """Membersihkan jawaban dari referensi dan format khusus"""
    # Format daftar bernomor
    formatted = re.sub(r'(\d+\.)\s', r'\n\1 ', raw_answer)
    # Hapus karakter khusus
    cleaned = re.sub(r'[*_]{2}', '', formatted)
    return cleaned.strip()

def ask(query):
    try:
        # Proses query langsung tanpa validasi awal
        result = qa.invoke({"query": query})
        if not result['source_documents']:
            return "Informasi tidak ditemukan dalam database resmi."
        # Pembersihan jawaban akhir
        return clean_answer(result['result'])

    except Exception as e:
        return f"Terjadi kesalahan sistem: {str(e)}\nSilakan coba lagi."

faq_df = pd.read_csv('../data/final_dataset_clean.csv')
def answer_from_doc(question):
    row = faq_df[faq_df['question'].str.lower() == question.lower()]
    if not row.empty:
        return row.iloc[-1]['answer']
    else:
        return "Tidak ada jawaban."

# %%
# TEST CASE 1: Pertanyaan di dalam konteks (formal dan informal)
print("\n\n UJI COBA 1: Pertanyaan yang Seharusnya Bisa Dijawab karena berasal dari dataset")
questions = [
    "Bagaimana cara menginstall aplikasi Jamsostek Mobile (JMO)?",
    "Bagaimana cara mengajukan klaim JHT melalui JMO jika memiliki lebih dari 1 kartu?",
    "Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?",
    "Jika anggota baru di JMO, apakah harus mendaftar di MotionPay?",
    "Apakah itu Promo?",
    "Apakah itu MotionPay?", 
    "Bagaimana jika lupa PIN EPS?",
    "Apakah sandi/PIN harus diubah secara berkala di kedua aplikasi?",
    "Dokumen apa sajakah persyaratan mengajukan JHT bagi PMI yang berpindah menjadi Warga Negara Asing?",
    "Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?",
    "Apa itu BPJS Ketenagakerjaan?",
    "Apa saja program BPJS Ketenagakerjaan?",
    "Siapakah yang dimaksud peserta BPJS Ketenagakerjaan?",
    "Apakah yang dimaksud dengan PHK?",
    "Apakah pegawai BHL (Buruh Harian Lepas) dapat mengikuti program JKP",
    "Bagaimana caranya badan usaha/pemberi kerja dapat menggunakan layanan Payment Reminder System(PRS)?",
    "Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?",
    "Apakah aplikasi Electronic Payment System (EPS)?",
    "Apa perbedaan program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP)?",
    "Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan?",
    "Bagaimana Mendaftarkan Bayi Baru Lahir?",
    "Apa itu GRC?",
    "Cara Membayar Iuran",
    "Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan?",
    "Kapan pembayaran iuran paling lambat?",
    "Bagaimana komitmen BPJS Kesehatan terkait gratifikasi?"
 
]

for q in questions:
    print(f"\n{'-'*5}")
    print(f"PERTANYAAN: {q}")
    chatbot_response = ask(q)
    print(f"JAWABAN CHATBOT:\n{chatbot_response}")
    print(f"\n{'-'*5}")

    
    # Membandingkan dengan jawaban asli (jika ada pertanyaan yang sama persis)
    actual_answer = answer_from_doc(q)
    if actual_answer != "Tidak ada jawaban yang cocok persis di dalam dataset.":
        print(f"\n{'='*50}")
        print(f"\nJawaban Sebenarnya (dari dataset): {actual_answer}")
        print(f"\n{'='*50}")
# Out:
#  UJI COBA 1: Pertanyaan yang Seharusnya Bisa Dijawab karena berasal dari dataset
#
# -----
# PERTANYAAN: Bagaimana cara menginstall aplikasi Jamsostek Mobile (JMO)?
# JAWABAN CHATBOT:
# Pertanyaan peserta sangat penting untuk dijawab. Berikut adalah jawaban yang tepat:
#
# Untuk menginstall aplikasi Jamsostek Mobile (JMO), silakan ikuti langkah-langkah berikut:
#
#
# 1.  Buka Playstore/ Appstore di perangkat Anda.
#
# 2.  Pencarian "Jamsostek Mobile" untuk menemukan aplikasi ini
#
# 3.  Klik aplikasi dan pilih "Instal"
#
# 4.  Jika terjadi masalah dengan instalasi, silakan hubungi Call Center BPJS Ketenagakerjaan atau kunjungi website https://sso.bpjsketenagakerjaan.go.id untuk mendapatkan bantuan lebih lanjut.
#
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Aplikasi Jamsostek Mobile (JMO) dapat diunduh dan diinstall melalui Playstore/ Appstore bagi pengguna smartphone .
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Bagaimana cara mengajukan klaim JHT melalui JMO jika memiliki lebih dari 1 kartu?
# JAWABAN CHATBOT:
# Pertanyaan peserta dapat dijawab sebagai berikut:
#
# Baik, kita dapat membantu Anda dengan mengajukan klaim JHT melalui JMO jika Anda memiliki lebih dari 1 kartu. Berikut adalah langkah-langkah yang perlu Anda lakukan:
#
#
# 1. Daftar ke layanan JMO: Pertama-tama, Anda perlu mendaftar ke layanan JMO BPJS Ketenagakerjaan untuk mengakses fitur pengajuan klaim secara online.
#
# 2. Masukkan informasi kartu: Setelah Anda mendaftar, masukkan informasi kartu kesehatan yang terkait dengan claim JHT yang ingin Anda ajukan.
#
# 3. Pilih jenis klaim: Pilih jenis klaim yang ingin Anda ajukan, yaitu Klaim JHT.
#
# 4. Isi formulir pengajuan: Isi formulir pengajuan klaim dengan semua informasi yang diperlukan, termasuk alasan dan dokumen pendukung jika memungkinkan.
#
# 5. Kirimkan klaim: Setelah selesai, kirimkan klaim Anda ke BPJS Ketenagakerjaan melalui JMO.
#
# Perlu diingat bahwa proses pengajuan klaim JHT melalui JMO sama dengan tata cara pada layanan saat ini, yaitu tidak ada perubahan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# JAWABAN CHATBOT:
# Pertanyaan peserta sangat relevan dengan konteks FAQ BPJS Ketenagakerjaan. Berikut adalah jawaban yang akurat dan informatif:
#
# Mohon maaf, saya tidak memiliki informasi mengenai promo spesifik yang tersedia pada aplikasi Jamsostek Mobile (JMO). Namun, saya dapat memberikan informasi umum tentang layanan JMO yang tersedia.
#
# Dengan menggunakan aplikasi JMO, peserta dapat mengakses berbagai layanan, termasuk:
#
#
# 1. Pendaftaran dan pengaturan kepesertaan program JKP.
#
# 2. Pengajuan kesehatan dan pengeluaran biaya medis.
#
# 3. Pengaksesan rekening online dan pengelolaan data pribadi.
#
# Untuk informasi lebih lanjut tentang promo atau spesifikasi layanan yang tersedia pada aplikasi JMO, saya sarankan Anda untuk menghubungi BPJS Ketenagakerjaan secara langsung melalui kontak yang tersedia di website resmi kami.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Promo yang tersedia merupakan produk dari berbagai merchant yang bekerjasama dengan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Jika anggota baru di JMO, apakah harus mendaftar di MotionPay?
# JAWABAN CHATBOT:
# Tentu, jika Anda ingin menghubungkan akun kamu dengan MotionPay, kamu perlu melakukan registrasi terlebih dahulu pada aplikasi JMO. Setelah berhasil mendaftarkan akun kamu di JMO, kamu dapat melakukan penautan akun linkage untuk dapat menikmati fitur Belanja di MotionPay.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Pengguna baru dapat mendaftar dengan mengakses fitur e-Wallet pada aplikasi JMO.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apakah itu Promo?
# JAWABAN CHATBOT:
# Baik, saya dapat menjawab pertanyaan Anda tentang Promo.
#
# Promo yang ditawarkan oleh BPJS Ketenagakerjaan adalah fitur promosi khusus untuk peserta BPJS Ketenagakerjaan. Fitur ini bertujuan untuk memberikan diskon dan penawaran menarik kepada peserta, sehingga dapat meningkatkan pengalaman mereka dalam menggunakan layanan BPJS Ketenagakerjaan.
#
# Promo yang tersedia merupakan produk dari berbagai merchant yang bekerjasama dengan BPJS Ketenagakerjaan. Setiap merchant memiliki syarat dan ketentuan penggunaan promo yang berbeda-beda, tetapi secara umum, syarat dan ketentuan diwajibkan adalah peserta BPJS Ketenagakerjaan.
#
# Jika Anda ingin mengetahui lebih lanjut tentang promo yang tersedia atau cara menggunakan promo tersebut, saya dapat membantu Anda.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Fitur promo ditujukan kepada peserta BPJS Ketenagakerjaan untuk mendapatkan diskon dan penawaran menarik
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apakah itu MotionPay?
# JAWABAN CHATBOT:
# Pertanyaan peserta: Apakah itu MotionPay?
#
# Jawaban: Ya, MotionPay adalah sistem pembayaran digital yang dikembangkan oleh BPJS Ketenagakerjaan. MotionPay memungkinkan pengguna melakukan transaksi online dengan mudah dan aman menggunakan akun digital mereka. Dengan MotionPay, pengguna dapat melakukan berbagai transaksi, termasuk pembayaran kesehatan, layanan sosial, dan lain-lain.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Aplikasi uang elektronik milik PT. MNC Teknologi Nusantara.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Bagaimana jika lupa PIN EPS?
# JAWABAN CHATBOT:
# Jika Anda tidak ingat PIN EPS, berikut adalah langkah-langkah yang dapat Anda ikuti untuk mengaktifkan kembali PIN Anda:
#
#
# 1.  Buka aplikasi BPJS Kesehatan di ponsel Anda.
#
# 2.  Pilih menu "My Account" (Akun Saya).
#
# 3.  Masukkan nomor KTP dan tanggal lahir untuk mengaktifkan PIN baru.
#
# 4.  Isi formulir penolakan PIN dengan benar.
#
# 5.  Tunggu konfirmasi dari sistem bahwa PIN telah aktif.
#
# Jika Anda masih memiliki masalah, silakan kontak Customer Service BPJS Kesehatan di (021) 799 5555.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Pada laman login EPS terdapat fitur "Lupa PIN", input Email user untuk dikirimkan kembali PIN melalui Email yang terdaftar.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apakah sandi/PIN harus diubah secara berkala di kedua aplikasi?
# JAWABAN CHATBOT:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Untuk keamanan dan kenyamanan pengguna, maka sandi/PIN harus diubah secara berkala di kedua aplikasi.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Dokumen apa sajakah persyaratan mengajukan JHT bagi PMI yang berpindah menjadi Warga Negara Asing?
# JAWABAN CHATBOT:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Peserta mengajukan permohonan pembayaran manfaat program JHT menggunakan formulir pengajuan manfaat dengan melampirkan persyaratan sebagai berikut:, Kartu Peserta BPJS Ketenagakerjaan; surat pindah kewarganegaraan dari instansi yang berwenang dan/atau bukti identitas sebagai warga negara asing; dan rekening tabungan atas nama PMI.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Promo apa saja yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# JAWABAN CHATBOT:
# Pertanyaan peserta sangat menarik! Berdasarkan konteks FAQ resmi yang telah disediakan, saya akan memberikan informasi yang relevan dan akurat.
#
# Untuk pertanyaan tersebut, saya tidak dapat menemukan informasi tentang promo spesifik yang tersedia pada aplikasi Jamsostek Mobile (JMO). Namun, saya dapat memberikan beberapa informasi umum tentang fitur-fitur yang tersedia di aplikasi JMO:
#
# •   Peserta dapat mengakses layanan Jamsostek Mobile (JMO) melalui website https://sso.bpjsketenagakerjaan.go.id
# •   Pada aplikasi ini, pekerja dapat memilih kepesertaan program JKP pada salah satu perusahaan.
# •   Selain itu, aplikasi juga menawarkan berbagai fitur lain seperti manajemen data diri, pengajuan kasus, dan informasi terkait layanan lainnya.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Promo yang tersedia merupakan produk dari berbagai merchant yang bekerjasama dengan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apa itu BPJS Ketenagakerjaan?
# JAWABAN CHATBOT:
# Selamat datang! Saya dengan senang hati membantu menjawab pertanyaan Anda tentang BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# BPJS Ketenagakerjaan adalah badan usaha milik negara yang bertugas sebagai penyelenggara sistem kesehatan dan ketenagakerjaan untuk warga Negara Indonesia. BPJS Ketenagakerjaan memiliki tugas utama dalam menyelenggarakan kesehatan dan ketenagakerjaan, serta memberikan jaminan kesehatan dan kenyamanan bagi peserta.
#
# BPJS Kesenata memiliki tiga jenis kepesertaan yaitu Peserta Pekerja (Pekerja yang bekerja pada tempat kerja), Peserta Penerima Upah Perorangan (PUP), dan Keluarga Besar Pengelola Kesehatan Perusahaan (KBP).
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): BPJS Ketenagakerjaan adalah badan hukum yang dibentuk untuk menyelenggarakan program Jaminan Kecelakaan Kerja, Jaminan Hari Tua, Jaminan Pensiun, Jaminan Kematian dan Jaminan Kehilangan Pekerjaan yang bertujuan untuk memberikan perlindungan paripurna kepada seluruh pekerja di Indonesia.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apa saja program BPJS Ketenagakerjaan?
# JAWABAN CHATBOT:
# Pertanyaan peserta sangat penting! Berikut adalah jawaban yang relevan berdasarkan konteks FAQ resmi:
#
# BPJS Ketenagakerjaan menawarkan beberapa program untuk membantu meningkatkan kesejahteraan penerima upah. Program-program tersebut antara lain:
#
#
# 1. Jaminan Sosial (Program 2): Memberikan perlindungan sosial kepada peserta, seperti pensiun, jaminan penyakit, dan jaminan kecelakaan kerja.
#
# 2. Asuransi Kesehatan (Program 3): Menyediakan asuransi kesehatan yang meliputi biaya rumah sakit, obat-obatan, dan layanan konsultasi dokter.
#
# 3. Jaminan Kelahiran (Program 4): Memberikan perlindungan kepada ibu dan bayi baru lahir, termasuk biaya rawat inap dan obat-obatan.
#
# 4. Pengajuan Bantuan Pemeliharaan Anak (Program 5): Membantu peserta dalam memenuhi kewajiban pemeliharaan anak mereka, seperti biaya pendidikan dan perawatan kesehatan.
#
# 5. Jaminan Kematian (Program 6): Menyediakan perlindungan kepada peserta untuk jaminan kematian yang meliputi biaya penguburan dan kebutuhan lainnya.
#
# Semoga informasi ini membantu Anda, peserta!
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Program yang diselenggarakan oleh BPJS Ketenagakerjaan terdiri dari 5 (lima) program, yaitu Jaminan Kecelakaan, Jaminan Hari Tua, Jaminan Pensiun, Jaminan Kematian dan dan Jaminan Kehilangan Pekerjaan.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Siapakah yang dimaksud peserta BPJS Ketenagakerjaan?
# JAWABAN CHATBOT:
# Pertanyaan peserta: Siapakah yang dimaksud peserta BPJS Ketenagakerjaan?
#
# Jawaban: Peserta BPJS Ketenagakerjaan adalah pekerja atau karyawan yang terdaftar dan memenuhi syarat untuk menerima jaminan kesehatan, kecelakaan kerja, dan pensiun melalui program BPJS Ketenagakerjaan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Program yang diselenggarakan oleh BPJS Ketenagakerjaan terdiri dari 5 (lima) program, yaitu Jaminan Kecelakaan, Jaminan Hari Tua, Jaminan Pensiun, Jaminan Kematian dan dan Jaminan Kehilangan Pekerjaan., Peserta BPJS Ketenagakerjaan terdiri dari:, Peserta Penerima Upah yang meliputi: Pekerja yang bekerja pada Pemberi Kerja penyelenggara negara meliputi: Pegawai pemerintah non-pegawai negeri Pejabat negara non-aparatur sipil negara dan Pegawai non-aparatur sipil negara pada lembaga tinggi negara atau lembaga negara. Pekerja yang bekerja pada Pemberi Kerja selain Penyelenggara Negara meliputi: Pekerja pada perusahaan Pekerja pada orang perseorangan Orang asing yang bekerja di Indonesia paling singkat 6 (enam) bulan Pekerja dalam masa percobaan Komisaris dan direksi yang menerima upah dan Pengawas dan pengurus yang menerima upah. Peserta Bukan Penerima Upah yang meliputi: Pemberi kerja Pekerja di luar hubungan kerja atau pekerja mandiri Pekerja yang tidak termasuk huruf b. yang bukan menerima upah. Pekerja Migran Indonesia adalah setiap warga negara Indonesia yang akan, sedang, atau telah melakukan pekerjaan dengan menerima upah di luar wilayah Republik Indonesia. Peserta Sektor Jasa Konstruksi meliputi Pekerja harian lepas, borongan, dan perjanjian kerja waktu tertentu di sektor Jasa Konstruksi.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apakah yang dimaksud dengan PHK?
# JAWABAN CHATBOT:
# Pertanyaan Peserta: Apakah yang dimaksud dengan PHK?
#
# Jawaban Profesional:
#
# PHK adalah singkatan dari "Pengunduran Diri Kerja". PHK adalah suatu kejadian di mana seorang pekerja memutuskan untuk meninggalkan pekerjaannya dan tidak akan kembali kepada tempat kerja tersebut. Dalam konteks ini, PHK juga dapat merujuk pada proses pengunduran diri oleh perusahaan dalam hal mengurangi atau membatalkan kehadiran seorang pegawai.
#
# Dalam konteks layanan BPJS Ketenagakerjaan, PHK merujuk pada suatu kejadian di mana seorang pekerja melakukan laporan pengunduran dirinya secara resmi melalui portal SIAPkerja.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Pengakhiran hubungan kerja karena suatu hal tertentu yang mengakibatkan berakhirnya hak dan kewajiban antara Pekerja/Buruh dan Pengusaha.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apakah pegawai BHL (Buruh Harian Lepas) dapat mengikuti program JKP
# JAWABAN CHATBOT:
# Pegawai BHL (Buruh Harian Lepas) dapat menjadi peserta Program JKP jika memenuhi eligibilitas sebagai disebutkan dalam Pasal 1 PP 37 Tahun 2021, yaitu memiliki hubungan kerja dan menerima upah atau imbalan bentuk lainnya. Oleh karena itu, semua pegawai BHL yang memenuhi kriteria ini dapat bergabung dengan program JKP sebagai hak mereka.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Bagaimana caranya badan usaha/pemberi kerja dapat menggunakan layanan Payment Reminder System(PRS)?
# JAWABAN CHATBOT:
# Pertanyaan peserta sangat relevan dengan konteks FAQ resmi BPJS Kesehatan dan BPJS Ketenagakerjaan. Berdasarkan informasi yang tersedia dalam konteks FAQ, jawaban dapat diberikan sebagai berikut:
#
# Untuk menggunakan layanan Payment Reminder System (PRS), pihak badan usaha/pemberi kerja dapat melakukan langkah-langkah berikut:
#
#
# 1. Mendaftar dan memasukkan data keuangan dan mutasi tenaga kerja dengan akurat, termasuk nomor NPWP, nomor KTP, dan lain-lain.
#
# 2. Mengaktifkan layanan PRS melalui sistem yang telah disediakan oleh BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# 3. Memeriksa ketersediaan informasi dan status pembayaran iuran yang tertera pada SMS Payment Reminder System (PRS).
#
# 4. Melakukan pembayaran iuran yang tertera pada SMS dengan menggunakan metode pembayaran yang tersedia, seperti transfer bank atau e-payment.
#
# 5. Membalas SMS Payment Reminder System (PRS) sesuai dengan format yang sudah ditentukan untuk memverifikasi pembayaran dan mendapatkan bukti pembayaran.
#
# Dengan melakukan langkah-langkah tersebut, badan usaha/pemberi kerja dapat menggunakan layanan PRS secara efektif dan efisien dalam mengelola iuran dan mutasi tenaga kerja.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Untuk menggunakan layanan Payment Reminder System (PRS) setiap bulannya, badan usaha/pemberi kerja dapat mendaftar melalui Petugas BPJS Ketenagakerjaan Kantor Cabang kepesertaan dengan menandatangani formulir pendaftaran PRS dan dipastikan menggunakan nomor handphone yang valid dan jika terjadi perubahan nomor handphone harap dilaporkan ke Petugas BPJS Ketenagakerjaan Kantor Cabang kepesertaan.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?
# JAWABAN CHATBOT:
# Terima kasih telah memilih BPJS Kesehatan dan BPJS Ketenagakerjaan sebagai pilihan layanan kesehatan Anda. Untuk pertanyaan Anda tentang pembayaran iuran BPU, saya akan menjelaskan langkah-langkah yang dapat Anda lakukan.
#
#
# 1.  Pembelian kartu digital: Sebelum melakukan pembayaran lanjutan, pastikan Anda telah membeli kartu digital BPJS Ketenagakerjaan dengan memasukkan Nomor Induk Kependudukan (NIK) yang ada di dalam Kartu Keluarga.
#
# 2.  Lakukan pembayaran lanjutan: Setelah memiliki kartu digital, Anda dapat melakukan pembayaran iuran lanjutan melalui kanal pembayaran iuran kerjasama yang tersedia. Pilih "Pembelian Baja" dan masukkan NIK untuk mendapatkan saldo JHT.
#
# 3.  Cek status pembayaran: Pastikan Anda telah melakukan pembayaran dengan benar, lalu cek apakah transaksi pembayaran iuran telah berubah masa perlindungan dan saldo JHT bertambah atau tidak.
#
# Jika setelah melakukan langkah-langkah di atas, masih terjadi masalah dengan transaksi pembayaran iuran BPU, silakan hubungi kantor BPJS Ketenagakerjaan untuk mendapatkan solusi yang tepat.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Peserta dapat menunjukkan tanda bukti pembayaran dari kanal pembayaran iuran dimana Peserta melakukan transaksi pembayaran iuran. Selanjutnya laporan akan ditindaklanjuti segera oleh tim BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apakah aplikasi Electronic Payment System (EPS)?
# JAWABAN CHATBOT:
# Ya, aplikasi Electronic Payment System (EPS) adalah salah satu cara untuk mengakses sistem pembayaran iuran BPJS Ketenagakerjaan secara Host to Host antara perbankan dengan BPJS Ketenagakerjaan. Aplikasi ini dapat diakses melalui website resmi BPJS Ketenagakerjaan atau melalui list aplikasi (EPS) yang ada pada footer website tersebut, yaitu:
#
# https://eps.bpjsketenagakerjaan.go.id
#
# Dengan menggunakan aplikasi EPS, perusahaan peserta dapat melakukan monitoring pembayaran iuran dengan lebih mudah dan efisien.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Electronic Payment System (EPS), adalah sistem pembayaran iuran BPJS Ketenagakerjaan secara Host to Host antara perbankan dengan BPJS Ketenagakerjaan. EPS disediakan untuk memudahkan perusahaan peserta dalam melakukan monitoring pembayaran iuran.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apa perbedaan program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP)?
# JAWABAN CHATBOT:
# Pertanyaan peserta sangat relevan dengan konteks FAQ BPJS Ketenagakerjaan. Berdasarkan informasi yang tersedia dalam konteks FAQ, dapat dipahamkan bahwa program Jaminan Hari Tua (JHT) dan Jaminan Pensiun (JP) memiliki beberapa perbedaan.
#
# Berikut adalah kesimpulan dasar tentang perbedaan program tersebut:
#
# - Tujuan: Program JHT bertujuan untuk memberikan bantuan keuangan kepada peserta yang ingin membeli rumah, sedangkan program JP memiliki tujuan untuk menggantikan penghasilan utama peserta setelah pensiun.
#
# - Kriteria Pengajuan Klaim:
#   - Program JHT:
#     a. Klaim sebagian 30%: Peserta yang telah memasuki usia 55 tahun dan ingin menggunakan keuntungan ini untuk membayar 30% dari jumlah total JHT yang perlu dibelanjakan untuk rumah.
#     b. Klaim sebagian 10%: Peserta yang telah memasuki usia 55 tahun dan ingin menggunakan keuntungan ini untuk keperluan lainnya sesuai persiapan memasuki usia pensiun, atau karena mengalami kesulitan keuangan.
#
# - Pencairan JHT dan JP: Pencairan kedua program dapat dilakukan secara bersamaan saat pengajuan klaim JP bagi peserta yang sudah memasuki usia pensiun. Ini berarti bahwa setelah pengajuan klaim, JHT akan diterbitkan sekaligus dengan JP, mengurangi beban keuangan pada peserta.
#
# - Pengajuan Klaim: Pengajuan klaim untuk kedua program dapat dilakukan di semua Kantor Cabang BPJS Ketenagakerjaan. Ini memudahkan para peserta dalam mengakses layanan dan keuntungan yang mereka butuhkan.
#
# Perlu diingat bahwa keteraturan dan syarat-syarat masing-masing program bisa berbeda, sehingga penting untuk memeriksa informasi terbaru dan spesifik dari Kantor Cabang BPJS Ketenagakerjaan yang Anda kunjungi.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Ditinjau dari manfaatnya, JHT merupakan manfaat uang tunai yang dibayarkan sekaligus pada saat pekerja memasuki usia pensiun, meninggal dunia, atau mengalami cacat total tetap., , Sedangkan manfaat JP adalah manfaat uang tunai yang dibayarkan setiap bulan kepada peserta yang memasuki usia pensiun, mengalami cacat total tetap, atau kepada Ahli Waris bagi peserta yang meninggal dunia., , Usia pensiun yang ditetapkan pertama kali adalah 56 tahun. Mulai 1 Januari 2019, usia pensiun bertambah menjadi 57 tahun. Usia pensiun dimaksud selanjutnya bertambah 1 (satu) tahun untuk setiap 3 (tiga) tahun berikutnya sampai mencapai usia pensiun maksimal 65 tahun.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan?
# JAWABAN CHATBOT:
# Pertanyaan peserta Anda sangat relevan dengan konteks FAQ resmi BPJS Kesehatan. Berikut adalah jawaban yang akurat dan informatif:
#
# BPJS Kesehatan menawarkan beberapa pelayanan kesehatan yang dapat dimanfaatkan oleh peserta, yaitu:
#
#
# 1.  Pelayanan Konsultasi Dokter: Peserta dapat mengunjungi fasilitas BPJS Kesehatan untuk melakukan konsultasi dengan dokter.
#
# 2.  Pelayanan Perawatan Bedah: Peserta dapat mendapatkan perawatan bedah di fasilitas BPJS Kesehatan yang terdaftar.
#
# 3.  Pelayanan Laboratorium: Peserta dapat melakukan tes laboratorium yang dibutuhkan untuk diagnosis penyakit tertentu.
#
# 4.  Pelayanan Diagnostik Radiologi: Peserta dapat menggunakan fasilitas diagnostik radiologi seperti CT Scan, MRI, dan X-Ray.
#
# Jika Anda memiliki pertanyaan lebih lanjut atau ingin meminta informasi lebih spesifik tentang pelayanan BPJS Kesehatan, silakan bertanya.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Bagaimana Mendaftarkan Bayi Baru Lahir?
# JAWABAN CHATBOT:
# Berikut adalah jawaban yang akurat dan informatif sesuai dengan kategori FAQ BPJS Kesehatan dan BPJS Ketenagakerjaan:
#
# Untuk mendaftar bayi baru lahir sebagai peserta JKN-KIS, Peserta harus melakukan langkah-langkah berikut:
#
#
# 1.  Bayi baru lahir dari Peserta JKN wajib didaftarkan kepada BPJS Kesehatan paling lama 28 hari sejak dilahirkan.
#
# 2.  Pendaftaran bayi dapat mengaktifkan status kepesertaan untuk mendapatkan manfaat jaminan pelayanan kesehatan selama 28 hari sejak bayi dilahirkan dan masih dalam perawatan.
#
# 3.  Status kepesertaan bayi baru lahir No. Kepesertaan JKN KIS harus dipastikan selambat-lambatnya 3 hari kerja sejak dirawat, atau 3 hari jika pulang rawat sebelum 3 hari.
#
# 4.  Iuran bagi bayi baru lahir dibayarkan oleh Peserta atau pihak lain atas nama Peserta pada saat mendaftar paling lama 28 dua puluh delapan hari sejak dilahirkan.
#
# 5.  Tidak mendaftar membayar iuran bayi baru lahir paling lama 28 hari sejak dilahirkan akan dikenakan kewajiban membayar iuran sejak bayi dilahirkan dan dikenakan sanksi
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apa itu GRC?
# JAWABAN CHATBOT:
# GRC adalah singkatan dari Good Risk Coverage, yaitu program penjaminan kebijakan risiko yang ditawarkan oleh BPJS Ketenagakerjaan. Program ini bertujuan untuk mendukung peserta kepesertaan dengan memberikan perlindungan finansial terhadap risiko kecelakaan atau penyakit yang dialami selama masa kerja.
#
# Dengan GRC, peserta dapat memperoleh manfaat penjaminan yang lebih baik dan lebih stabil, sehingga mereka dapat merasa lebih aman dan nyaman dalam melakukan kegiatan kerja. Program ini juga membantu Pemberi Kerja untuk memiliki kontrol yang lebih baik atas risiko kecelakaan atau penyakit yang dialami oleh karyawan.
#
# GRC tersedia bagi semua peserta kepesertaan BPJS Ketenagakerjaan, termasuk mereka yang baru mendaftar dan mereka yang sudah berpengalaman dalam melakukan kegiatan kerja.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Cara Membayar Iuran
# JAWABAN CHATBOT:
# Pertanyaan Peserta: Cara Membayar Iuran
#
# Jawaban Profesional:
#
# Untuk memahami cara membayar iuran, kita perlu mempelajari struktur dan rincian tentang iuran yang dikenakan oleh BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Berikut adalah informasi tentang cara membayar iuran dan beberapa hal yang perlu Anda ketahui:
#
#
# 1.  Iuran Jaminan Kesehatan: Iuran kesehatan yang harus dibayar oleh peserta tergantung pada golongan usia, jenis pekerjaan, dan kondisi kesehatannya.
#
# 2.  Bulan-bulan iuran: Pertimbangkan jika Anda memiliki masa iuran yang tidak tetap. Banyak perusahaan mempertimbangkan jam kerja bulanan untuk menentukan masa iuran yang dikenakan kepada pegawai.
#
# 3.  Penggantian dengan bunga: Beberapa kemitraan memberikan penggantian dengan bunga pada tahun tertentu, tetapi informasi ini akan disediakan secara spesifik oleh perusahaan Anda dan dapat berbeda tergantung pada kontrak yang Anda tanda tangani.
#
# 4.  Penggantian dengan bunga: Beberapa kemitraan memberikan penggantian dengan bunga pada tahun tertentu, tetapi informasi ini akan disediakan secara spesifik oleh perusahaan Anda dan dapat berbeda tergantung pada kontrak yang Anda tanda tangani.
#
# 5.  Penggantian dengan bunga: Beberapa kemitraan memberikan penggantian dengan bunga pada tahun tertentu, tetapi informasi ini akan disediakan secara spesifik oleh perusahaan Anda dan dapat berbeda tergantung pada kontrak yang Anda tanda tangani.
#
# Dalam hal cara membayar iuran, di samping membayar secara tunai, pengguna juga dapat menggunakan metode pembayaran lain seperti transfer bank.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Pembayaran iuran bagi peserta dapat dilakukan dengan tahapan sebagai berikut I. Peserta dan calon peserta PBPU Kelas I dan II wajib menggunakan fasilitas pembayaran auto debit banknon bank. II. Peserta melakukan registrasi autodebet melalui a. Kantor BPJS Kesehatan dengan mengisi form autodebit yang tersedia dengan melengkapi persyaratan pendaftaran berupa Fotocopy Kartu KeluargaKTP dan Buku Rekening b. Kanal Online seperti Mobile JKN Website BPJS Kesehatan Kanal Bank Aplikasi E-Commerce USSD III. Iuran pertama peserta akan otomatis terdebit pada periode tanggal 5 atau tanggal 20 setiap bulannya IV. Untuk kelancaran proses pendaftaran Autodebit pada Bank Pastikan Nomor Telepon yang digunakan benar atau sesuai dengan Nomoor Telepon yang digunakan saat pembukaan rekening di Bank untuk menerima Pin OTP dan pastikan memiliki saldo pulsa.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Apa saja pelayanan BPJS Kesehatan yang dapat dimanfaatkan?
# JAWABAN CHATBOT:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Kapan pembayaran iuran paling lambat?
# JAWABAN CHATBOT:
# Pembayaran iuran paling lambat tanggal 10 (sepuluh) setiap bulan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# PERTANYAAN: Bagaimana komitmen BPJS Kesehatan terkait gratifikasi?
# JAWABAN CHATBOT:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# -----
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------

# %% [markdown]
# TOTAL SOAL : 26
# (ada di dataset jawabannya + jawaban terjawab atau tidak)
# - Pertanyaan -jawaban ada di dataset dan terjawab:13
# - Pertanyaan -jawaban tidak ada di dataset dan terjawab:6
# - Pertanyaan - jawaban ada di dataset dan tidak terjawab:5
# - Pertanyaan  tidak ada di dataset dan tidak terjawab:2

# %%
# TEST CASE 2: Pertanyaan di luar konteks (untuk menguji penolakan)
# Pertanyaan ini untuk memastikan chatbot tidak mengarang jawaban.
print("\n\n UJI COBA 2: Pertanyaan di Luar Konteks ")
questions_out_of_context = [
    "Apa itu Allo Bank?",
    "Bagaimana cara mengajukan KPR?",
    "Siapa penemu listrik?",
    "Apa saja manfaat dari olahraga?",
    "Bagaimana cara membuat kue?",
    "Jelaskan apa itu Quantum Computing?",
    "Apa yang dimaksud dengan Machine Learning?",
    "Gimana cara buat foto HD dengan AI?",
    "Apa itu teknologi blockchain?",
    "Apa itu teknologi quantum?",
    "Apa kopi paling enak saat ini?",
    "Sebutkan Sepatu lari paling enak",
    "Kapan Indonesia Merdeka?",
    "Dimana kantor urusan agama terdekat",
    "Jelaskan tentang skema piala dunia?",
    "Siapa pencetak gol terbanyak piala dunia 2022?",
    "Jumlah total trofi Liverpool berapa?",
    "Hitung luas Kota Surabaya",
    "Dimana tempat syuting film laskar Pelangi?",
    "Dimana bom atom amerika saat perang dunia kedua dibuat?",
    "Bagaimana cara membedakan biji kopi?",
    "Jembatan merah ada Dimana?",
    "Siapa presiden Indonesia pertama?",
    "Siapa penemu alat musik gitar?",
    "Hitung luas lapangan bola."
]

for q in questions_out_of_context:
    print(f"\n{'-'*5}")
    print(f"Pertanyaan: {q}")
    chatbot_answer = ask(q)
    print(f"Jawaban Chatbot:\n{chatbot_answer}")

    # Membandingkan dengan jawaban asli (jika ada pertanyaan yang sama persis)
    actual_answer = answer_from_doc(q)
    if actual_answer != "Tidak ada jawaban yang cocok persis di dalam dataset.":
        print(f"\n{'-'*50}")
        print(f"\nJawaban Sebenarnya (dari dataset): {actual_answer}")
        print(f"\n{'-'*50}")
# Out:
#  UJI COBA 2: Pertanyaan di Luar Konteks
#
# -----
# Pertanyaan: Apa itu Allo Bank?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Bagaimana cara mengajukan KPR?
# Jawaban Chatbot:
# Pertanyaan Peserta: Bagaimana cara mengajukan KPR?
#
# Jawaban Profesional:
#
# Untuk mengajukan Klaim Pekerjaan Residu (KPR), peserta dapat melakukan langkah-langkah berikut:
#
#
# 1.  Peserta harus memastikan bahwa mereka telah memenuhi syarat untuk menerima manfaat JKP.
#
# 2.  Pastikan semua data dan dokumen yang diperlukan sudah lengkap dan sesuai dengan persyaratan BPJS Ketenagakerjaan.
#
# 3.  Peserta dapat mengajukan klaim KPR melalui Sistem Informasi Ketenagakerjaan (SIK) atau melalui pihak pemberi kerja mereka.
#
# 4.  Peserta harus memasukkan informasi yang diperlukan, termasuk tanggal mulai dan akhir masa kepesertaan program JKP, serta alasan untuk mengajukan klaim KPR.
#
# 5.  Setelah melengkapi formulir pendaftaran, peserta dapat mengajukan klaim KPR melalui SIK atau melalui pihak pemberi kerja mereka.
#
# 6.  BPJS Ketenagakerjaan akan memproses klaim dan memberikan keputusan apakah klaim telah disetujui atau tidak.
#
# Perlu diingat bahwa peserta harus memeriksa kembali informasi yang diperlukan sebelum mengajukan klaim KPR untuk memastikan semua data yang lengkap dan sesuai dengan persyaratan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Siapa penemu listrik?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa saja manfaat dari olahraga?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai "manfaat dari olahraga". Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Bagaimana cara membuat kue?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai resep atau prosedur membuat kue. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda memiliki pertanyaan lain terkait dengan manfaat JKP, JKK, atau layanan lainnya dari BPJS Kesehatan dan BPJS Ketenagakerjaan, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Jelaskan apa itu Quantum Computing?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai "Quantum Computing" dalam konteks FAQ resmi BPJS Kesehatan dan BPJS Ketenagakerjaan. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda memiliki pertanyaan lain terkait dengan layanan kami, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa yang dimaksud dengan Machine Learning?
# Jawaban Chatbot:
# Pertanyaan Anda tentang "Machine Learning" adalah topik yang relevan dengan konteks BPJS Kesehatan dan BPJS Ketenagakerjaan, meskipun tidak secara langsung terkait dengan layanan kami. Namun, saya dapat memberikan penjelasan singkat tentang konsep Machine Learning dan bagaimana prinsip-prinsipnya terkait dengan pekerjaan kami.
#
# Machine Learning adalah suatu teknologi yang memungkinkan komputer untuk belajar dari data dan membuat prediksi atau keputusan tanpa perlu dikodekan secara eksplisit. Dalam konteks bisnis, Machine Learning digunakan untuk menganalyisis data dan membuat keputusan yang lebih akurat.
#
# Dalam prinsip-prinsip BPJS Kesehatan dan BPJS Ketenagakerjaan, terutama dalam hal prinsip "informasi terbaik yang tersedia" (prinsip ke-6), penting untuk memastikan bahwa kami selalu menggunakan teknologi dan metode yang paling efektif untuk mengolahan data dan membuat keputusan. Meskipun Machine Learning bukanlah aspek langsung dari layanan kami, fokus pada pengembangan berkelanjutan (prinsip ke-8) dan integrasi dengan teknologi lainnya membantu kami untuk tetap relevan dengan perkembangan teknologi.
#
# Mohon diingat bahwa konteks spesifik pertanyaan Anda tidak dimasukkan dalam FAQ resmi kami, sehingga jawaban saya ini berdasarkan penjelasan umum tentang Machine Learning dan bagaimana konsep tersebut terkait dengan prinsip-prinsip yang kita jalankan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Gimana cara buat foto HD dengan AI?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai cara membuat foto HD dengan AI. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Perlu diingat bahwa pertanyaan Anda tidak tercakup dalam konteks FAQ resmi yang tersedia. Jika Anda memiliki pertanyaan lain tentang layanan BPJS Kesehatan atau BPJS Ketenagakerjaan, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa itu teknologi blockchain?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa itu teknologi quantum?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai "teknologi quantum" dalam konteks layanan BPJS Kesehatan dan BPJS Ketenagakerjaan. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda memiliki pertanyaan lain tentang layanan kami, saya akan senang membantu!
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa kopi paling enak saat ini?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Sebutkan Sepatu lari paling enak
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai sepaut lari paling enak. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda memiliki pertanyaan lain yang terkait dengan layanan kami, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Kapan Indonesia Merdeka?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hari pernikahan Siwabessy. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda ingin mengetahui informasi tentang Indonesia Merdeka, saya dapat memberikan informasi berikut:
#
# Indonesia Merdeka pada tanggal 17 Agustus 1945.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Dimana kantor urusan agama terdekat
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai lokasi Kantor Urusan Agama terdekat. Namun, kami dapat membantu Anda menemukan informasi yang relevan melalui layanan informasi online resmi BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Untuk menemukan lokasi Kantor Urusan Agama terdekat, Anda dapat mengunjungi situs web resmi Pemerintah Republik Indonesia atau aplikasi resmi mereka. Selain itu, Anda juga dapat mencoba menghubungi layanan informasi publik yang tersedia di sekitar Anda untuk mendapatkan informasi terkait lokasi dan kontak Kantor Urusan Agama terdekat.
#
# Kami berharap informasi ini membantu Anda dalam menemukan informasi yang relevan. Jika Anda memiliki pertanyaan lain, jangan ragu untuk bertanya!
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Jelaskan tentang skema piala dunia?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Siapa pencetak gol terbanyak piala dunia 2022?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Jumlah total trofi Liverpool berapa?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Hitung luas Kota Surabaya
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Dimana tempat syuting film laskar Pelangi?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai lokasi syuting film Laskar Pelangi. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan. Jika Anda memiliki pertanyaan lain yang terkait dengan layanan kami, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Dimana bom atom amerika saat perang dunia kedua dibuat?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan. Pertanyaan Anda tentang bom atom Amerika saat Perang Dunia Kedua tidak tercakup dalam konteks FAQ resmi yang saya miliki.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Bagaimana cara membedakan biji kopi?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Jembatan merah ada Dimana?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai lokasi jembatan Merah yang dimaksudkan oleh pertanyaan peserta. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda memiliki pertanyaan lain tentang layanan BPJS Kesehatan dan BPJS Ketenagakerjaan, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Siapa presiden Indonesia pertama?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Siapa penemu alat musik gitar?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai penemuan alat musik gitar. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Hitung luas lapangan bola.
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai "Hitung luas lapangan bola". Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------

# %% [markdown]
# Total pertanyaan diluar konteks dataset : 25
# - Pertanyaan terjawab:3
#
# - Pertanyaan tidak terjawab:22

# %%
# TEST CASE 3: Pertanyaan dalam konteks namun ada kesalahan penulisan
print("\n\n UJI COBA 3: Pertanyaan Masih dalam Konteks namun terdapat kesalahan penulisan ")
questions_context_typo = [
    "Aph itu BPJS Ketenagakerajaan?",
    "Apa sajak program BPJS Ketenagakerjaan?",
    "Siapakah yang dimaksud peserta BPJS Ketenagakerajaan?",
    "Apakh yang dimaksud dengan PHK?",
    "Apakah pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP?",
    "Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?", 
    "Gimana jika lupa PIN EPS?",
    "Apakah itu Perumahan Pekerja?",
    "Dokumen apa sajakah persyaratan mengajukan JHT bagi PMI yang berpindah menjadi Warga Negara Asing?",
    "Kapan BSU tahun 2025 dibagikan?",
    "Dimana obat batuk pertama kali ditemukan",
    "Jika flu sebaiknya minum obat herbal apa",
    "Sopo peserta BPJS ketenagakerjaan",
    "Sejak tanggal berapa pembayaran iuran paling lambat ?",
    "Jika anggota baru di JMO, apakah harus mendaftar di MotionIme?",
    "Apakah itu ShoopePay?",
    "Apa perbedaan program Jaminan Dari Tua (JHT) dan Jaminan Pensiun (JP)?",
    "Gimana pembayaran iuran?",
    "Tanggal pembayaran iuran paling lambat ?",
    "Promo apa sajak yang tersedia pada aplikasi Jamsostek Mobile (JMO)?"
    
]

for q in questions_context_typo:
    print(f"\n{'-'*5}")
    print(f"Pertanyaan: {q}")
    chatbot_answer = ask(q)
    print(f"Jawaban Chatbot:\n{chatbot_answer}")

    
    # Membandingkan dengan jawaban asli (jika ada pertanyaan yang sama persis)
    actual_answer = answer_from_doc(q)
    if actual_answer != "Tidak ada jawaban yang cocok persis di dalam dataset.":
        print(f"\n{'-'*50}")
        print(f"\nJawaban Sebenarnya (dari dataset): {actual_answer}")
        print(f"\n{'-'*50}")
# Out:
#  UJI COBA 3: Pertanyaan Masih dalam Konteks namun terdapat kesalahan penulisan
#
# -----
# Pertanyaan: Aph itu BPJS Ketenagakerajaan?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa sajak program BPJS Ketenagakerjaan?
# Jawaban Chatbot:
# Pertanyaan peserta sangat penting! Berikut adalah jawaban profesional:
#
# BPJS Ketenagakerjaan memiliki beberapa program yang ditujukan untuk penerima upah, yaitu:
#
#
# 1. BPJS Ketenagakerjaan Sederhana
#
# 2. BPJS Ketenagakerjaan Premium
#
# 3. BPJS Ketenagakerjaan Plus
#
# Setiap program ini memiliki kelebihan dan manfaat yang berbeda-beda. Untuk mendapatkan informasi lebih lanjut tentang setiap program, Anda dapat mengunjungi situs web resmi BPJS Ketenagakerjaan atau menghubungi customer service kami.
#
# Perlu diingat bahwa BPJS Ketenagakerjaan hanya mengeluarkan 1 (satu) kartu peserta untuk seluruh program yang diikuti oleh pemberi kerja/badan usaha, seperti yang telah disebutkan dalam FAQ.
#
# Jika Anda memiliki pertanyaan lebih lanjut atau ingin mendapatkan informasi lebih detail tentang setiap program, silakan bertanya!
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Siapakah yang dimaksud peserta BPJS Ketenagakerajaan?
# Jawaban Chatbot:
# Pertanyaan peserta: Siapakah yang dimaksud peserta BPJS Ketenagakerjaan?
#
# Jawaban: Sesuai dengan konteks FAQ resmi, peserta BPJS Ketenagakerjaan adalah orang-orang yang terdaftar sebagai anggota BPJS Ketenagakerjaan dan memenuhi syarat untuk mendapatkan jaminan sosial.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apakh yang dimaksud dengan PHK?
# Jawaban Chatbot:
# Pertanyaan Peserta: Apakah yang dimaksud dengan PHK?
#
# Jawaban Profesional:
# PHK adalah singkatan dari "Pengunduran Diri Kerja", yaitu pengumuman kepada pekerja bahwa hubungan kerja antara mereka dan perusahaan akan berakhir karena alasan tertentu, seperti penyerahan tugas, kematian, atau alasan lain yang memungkinkan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apakah pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP?
# Jawaban Chatbot:
# Berdasarkan informasi yang tersedia dalam konteks FAQ resmi BPJS Ketenagakerjaan, jawaban adalah:
#
# Ya, pegawai BHL (Burung Harian Lepas) dapat mengikuti program JKP (Jaminan Kesehatan Pertahanan Tenaga Kerja) jika memenuhi eligibilitas.
#
# Menurut informasi terkait dari FAQ BPJS Ketenagakerjaan: "Program JKP merupakan hak setiap peserta pada segmen PU yang telah memenuhi eligibilitas."
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?
# Jawaban Chatbot:
# Berikut adalah jawaban profesional untuk pertanyaan peserta:
#
# Pertanyaan Peserta: Peserta BPU sudah melakukan pembayaran iuran namun transaksi pembayaran iuran belum merubah masa perlindungan/saldo JHT belum bertambah, apakah yang harus dilakukan?
#
# Jawaban:
#
# 1. Pastikan transaksi pembayaran iuran telah berhasil dan dibukti dengan bukti transaksi yang dapat diperiksa oleh BPJS Ketenagakerjaan.
#
# 2. Cek saldo JHT secara online melalui akun peserta di situs web resmi BPJS Ketenagakerjaan atau menggunakan aplikasi mobile BPJS Ketenagakerjaan.
#
# 3. Jika saldo JHT belum bertambah, hubungi Customer Service BPJS Ketenagakerjaan untuk meminta bantuan dan informasi terkait transaksi pembayaran iuran yang telah dilakukan.
#
# 4. Pastikan peserta memiliki bukti transaksi pembayaran iuran yang dapat diperiksa oleh BPJS Ketenagakerjaan.
#
# Dengan melakukan langkah-langkah di atas, peserta BPU dapat memastikan bahwa transaksi pembayaran iuran telah berhasil dan saldo JHT sudah bertambah.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Peserta dapat menunjukkan tanda bukti pembayaran dari kanal pembayaran iuran dimana Peserta melakukan transaksi pembayaran iuran. Selanjutnya laporan akan ditindaklanjuti segera oleh tim BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Gimana jika lupa PIN EPS?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda ingin reset PIN EPS, silakan masuk ke halaman utama EPS, pilih menu lupa PIN untuk melakukan reset PIN.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apakah itu Perumahan Pekerja?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai "Perumahan Pekerja". Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Fitur pengajuan manfaat perumahan pekerja untuk fasilitas pembiayaan perumahan yang diberikan oleh BPJS Ketenagakerjaan kepada peserta program JHT.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Dokumen apa sajakah persyaratan mengajukan JHT bagi PMI yang berpindah menjadi Warga Negara Asing?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Peserta mengajukan permohonan pembayaran manfaat program JHT menggunakan formulir pengajuan manfaat dengan melampirkan persyaratan sebagai berikut:, Kartu Peserta BPJS Ketenagakerjaan; surat pindah kewarganegaraan dari instansi yang berwenang dan/atau bukti identitas sebagai warga negara asing; dan rekening tabungan atas nama PMI.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Kapan BSU tahun 2025 dibagikan?
# Jawaban Chatbot:
# Berdasarkan informasi yang tersedia dalam konteks FAQ resmi, persyaratan penerima BSU untuk tahun 2025 hanya ada satu kepesertaan aktif. Sementara itu, waktu penyaluran BSU bagi peserta yang memenuhi syarat tidak ditentukan secara spesifik dalam konteks ini.
#
# Pertanyaan Peserta: Kapan BSU tahun 2025 dibagikan?
#
# Jawaban:
# Mohon maaf, saya tidak memiliki informasi mengenai tanggal atau waktu penyaluran BSU tahun
# 2025. Saya hanya dapat menyebutkan bahwa persyaratan penerima BSU untuk tahun 2025 hanya ada satu kepesertaan aktif dan peserta yang memenuhi syarat hanya akan mendapatkan BSU untuk 1 (satu) kepesertaan aktif. Untuk informasi lebih lanjut, silakan menghubungi layanan pelanggan BPJS Kesehatan atau BPJS Ketenagakerjaan secara langsung.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Dimana obat batuk pertama kali ditemukan
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai tempat penemuan obat batuk. Informasi tersebut tidak tercakup dalam konteks FAQ resmi yang tersedia untuk BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Jika flu sebaiknya minum obat herbal apa
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai obat herbal yang direkomendasikan untuk pengobatan flu. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Namun, saya dapat memberikan informasi umum bahwa flu adalah penyakit infeksi yang disebabkan oleh virus. Untuk pengobatan flu, biasanya dianjurkan untuk minum obat-obatan yang direkomendasikan oleh dokter atau profesional kesehatan lainnya.
#
# Jika Anda memiliki pertanyaan lebih lanjut tentang layanan BPJS Kesehatan dan BPJS Ketenagakerjaan, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Sopo peserta BPJS ketenagakerjaan
# Jawaban Chatbot:
# Salam!
#
# Mohon maaf, saya tidak memiliki informasi tentang "Sopo peserta BPJS Ketenagakerjaan". Sop yang terkait dengan BPJS Ketenagakerjaan adalah Sop Pengajuan Manfaat.
#
# Jika Anda ingin memahami lebih lanjut tentang proses pengajuan manfaat, berikut adalah langkah-langkahnya:
#
#
# 1.  Cek status pengajuan Anda di Siapkerja.
#
# 2.  Pastikan semua informasi yang diminta sudah lengkap dan benar.
#
# 3.  Klik "Pengajuan Manfaat" pada menu utama aplikasi Siapkerja.
#
# 4.  Pilih jenis manfaat yang ingin diperoleh.
#
# 5.  Isi data pribadi dan informasi keluarga sesuai dengan kebutuhan Anda.
#
# 6.  Pastikan semua formulir dan dokumen yang diminta sudah lengkap dan benar.
#
# 7.  Klik "Kirim" untuk mengajukan manfaat.
#
# Jika Anda memiliki pertanyaan atau kesulitan dalam proses pengajuan manfaat, silakan hubungi Kantor BPJS Ketenagakerjaan terdekat untuk mendapatkan bantuan yang lebih spesifik.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Sejak tanggal berapa pembayaran iuran paling lambat ?
# Jawaban Chatbot:
# Pembayaran iuran paling lambat tanggal 10 (sepuluh) setiap bulan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Jika anggota baru di JMO, apakah harus mendaftar di MotionIme?
# Jawaban Chatbot:
# Pertanyaan peserta telah ditanggapi sebagai berikut:
#
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Namun, saya dapat memberikan informasi umum yang terkait dengan topik ini. Jika Anda baru mendaftar di JMO (Jasa Manfaat Pajak), maka Anda tidak perlu mendaftar di MotionIme secara bersamaan. Pendaftaran di MotionIme hanya diperlukan jika Anda ingin menikmati fitur Belanja di aplikasi kami, sebagai bagian dari penautan akun linkage MotionPay dengan akun JMO.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apakah itu ShoopePay?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai "ShoopePay". Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Apa perbedaan program Jaminan Dari Tua (JHT) dan Jaminan Pensiun (JP)?
# Jawaban Chatbot:
# Pertanyaan Peserta: Apa perbedaan program Jaminan Dari Tua (JHT) dan Jaminan Pensiun (JP)?
#
# Jawaban: Kedua program tersebut memiliki tujuan yang sama, yaitu memberikan perlindungan sosial kepada peserta. Namun, ada beberapa perbedaan antara keduanya.
#
#
# 1.  Tujuan: Program JHT bertujuan untuk membantu tenaga kerja aktif mempersiapkan diri untuk hidup setelah berhenti bekerja, sedangkan program JP bertujuan untuk memberikan perlindungan sosial kepada peserta yang sudah berusia pensiun.
#
# 2.  Persyaratan: Program JHT tidak memiliki persyaratan minimal kepesertaan, sementara program JP memiliki persyaratan minimal kepesertaan 10 tahun pada program JHT untuk mendapatkan bunga bulanan.
#
# 3.  Porsi kontribusi: Porsi kontribusi bagi peserta yang berdaftar di program JHT adalah 30% dan peserta dengan minimal kepesertaan 10 tahun dapat mengajukan paling banyak 10%.
#
# 4.  Penggunaan dana: Program JHT dan JP menggunakan dana secara independen.
#
# Dengan memahami perbedaan antara program JHT dan JP, peserta dapat memilih program yang paling sesuai dengan kebutuhannya.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Gimana pembayaran iuran?
# Jawaban Chatbot:
# Mohon maaf, saya tidak memiliki informasi mengenai hal tersebut. Saya hanya dapat menjawab pertanyaan seputar layanan BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# Jika Anda ingin tahu tentang cara pembayaran iuran, saya sarankan Anda untuk mencari informasi yang lebih spesifik di FAQ atau situs web resmi BPJS Kesehatan dan BPJS Ketenagakerjaan.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Tanggal pembayaran iuran paling lambat ?
# Jawaban Chatbot:
# Pertanyaan peserta: Tanggal pembayaran iuran paling lambat ?
#
# Jawaban: Pembayaran iuran paling lambat tanggal 10 (sepuluh) setiap bulan. Tangani pemilik rekening yang bersangkutan. Surat kuasa wajib ditanda tangani oleh pemilik rekening walaupun calon peserta yang mendaftar bukan pemilik rekening. Calon peserta dapat melakukan pembayaran iuran pertama dalam waktu paling cepat 14 empat belas hari atau paling lambat 30 tiga puluh hari setelah pendaftaran.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------
#
# -----
# Pertanyaan: Promo apa sajak yang tersedia pada aplikasi Jamsostek Mobile (JMO)?
# Jawaban Chatbot:
# Pertanyaan peserta sangat relevan dengan konteks FAQ resmi yang telah disediakan.
#
# Berdasarkan informasi yang tersedia dalam FAQ, promosi yang tersedia pada aplikasi Jamsostek Mobile (JMO) tidak secara spesifik dijabarkan. Namun, dapat disimpulkan bahwa sebagai peserta program JKP, Anda dapat mengakses berbagai layanan dan fasilitas melalui aplikasi JMO, termasuk akses ke informasi tentang kesehatan, keamanan sosial, dan lain-lain.
#
# Mohon maaf, saya tidak memiliki informasi yang lebih spesifik tentang promo atau diskon yang tersedia pada aplikasi JMO. Untuk mendapatkan informasi terbaru dan spesifik tentang promo, saya sarankan Anda untuk mengunjungi situs web resmi BPJS Ketenagakerjaan atau mengakses aplikasi JMO sendiri.
#
# Jika Anda memiliki pertanyaan lain yang lebih relevan dengan konteks FAQ, saya akan senang membantu.
#
# --------------------------------------------------
#
# Jawaban Sebenarnya (dari dataset): Tidak ada jawaban.
#
# --------------------------------------------------

# %% [markdown]
# Total pertanyaan salah tidak baku/typo : 20
#
# - Pertanyaan -jawaban ada di dataset dan terjawab:1
# - Pertanyaan -jawaban tidak ada di dataset dan terjawab:11
# - Pertanyaan - jawaban ada di dataset dan tidak terjawab:2
# - Pertanyaan - tidak ada di dataset dan tidak terjawab:6

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# Berdasarkan serangkaian pengujian terhadap chatbot yang dibangun menggunakan model LLAMA 3.2 dan berbasis pada dataset FAQ tertentu, dapat disimpulkan bahwa:
#
# 1. Kemampuan Memahami Pertanyaan - Chatbot mampu menjawab sebagian besar pertanyaan yang ada di dataset, namun akurasi jawaban masih bervariasi. Beberapa jawaban kurang tepat meskipun informasi tersedia dalam data.
# 2. Kemampuan Menjaga Batasan Konteks - Model belum sepenuhnya konsisten dalam menjaga batasan topik. Masih terdapat beberapa pertanyaan di luar konteks yang tetap dijawab, menunjukkan perlunya penyempurnaan dalam kontrol domain.
#
# 3. Kemampuan Menolak dan Menyampaikan Ketidaktahuan - Model cenderung tetap menjawab meskipun tidak memiliki informasi yang relevan. Bahkan, dalam beberapa kasus memberikan dua jenis jawaban: penjelasan dan pernyataan bahwa model tidak tahu, yang dapat membingungkan pengguna.
#
# 4. Kemampuan Mengatasi Pertanyaan dengan Typo - Chatbot cukup tangguh terhadap pertanyaan dengan typo ringan atau bahasa tidak baku, namun akurasi menurun jika kesalahan penulisan mengubah makna.
#
# Model LLAMA 3.2
#
# Kelebihan:
#
# * Mampu memahami pertanyaan dalam konteks, termasuk dengan typo ringan.
# * Responsif dan tetap menjawab meski format pertanyaan tidak baku.
#
# Kelemahan:
#
# * Tidak konsisten dalam menolak pertanyaan di luar konteks.
# * Beberapa jawaban kurang akurat meski informasi tersedia.
# * Memberikan respons ganda (jawaban + pengakuan tidak tahu).
